# %% [markdown]
# ## Module 4 - Assignment Helper Functions
# #### We begin by including the functions to generate frequent itemsets (via the Apriori algorithm) and resulting association rules:

# %%
# (c) 2016 Everaldo Aguiar & Reid Johnson
#
# Modified from:
# Marcel Caraciolo (https://gist.github.com/marcelcaraciolo/1423287)
#
# Functions to compute and extract association rules from a given frequent itemset 
# generated by the Apriori algorithm.
#
# The Apriori algorithm is defined by Agrawal and Srikant in:
# Fast algorithms for mining association rules
# Proc. 20th int. conf. very large data bases, VLDB. Vol. 1215. 1994

import csv
import numpy as np

def load_dataset(filename):
    '''Loads an example of market basket transactions from a provided csv file.

    Returns: A list (database) of lists (transactions). Each element of a transaction is 
    an item.
    '''

    with open(filename,'r') as dest_f:
        data_iter = csv.reader(dest_f, delimiter = ',', quotechar = '"')
        data = [data for data in data_iter]
        data_array = np.asarray(data)
        
    return data_array

def apriori(dataset, min_support=0.5, verbose=False):
    """Implements the Apriori algorithm.

    The Apriori algorithm will iteratively generate new candidate 
    k-itemsets using the frequent (k-1)-itemsets found in the previous 
    iteration.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate 
        candidate itemsets.

    min_support : float
        The minimum support threshold. Defaults to 0.5.

    Returns
    -------
    F : list
        The list of frequent itemsets.

    support_data : dict
        The support data for all candidate itemsets.

    References
    ----------
    .. [1] R. Agrawal, R. Srikant, "Fast Algorithms for Mining Association 
           Rules", 1994.

    """
    C1 = create_candidates(dataset)
    D = list(map(set, dataset))
    F1, support_data = support_prune(D, C1, min_support, verbose=False) # prune candidate 1-itemsets
    F = [F1] # list of frequent itemsets; initialized to frequent 1-itemsets
    k = 2 # the itemset cardinality
    while (len(F[k - 2]) > 0):
        Ck = apriori_gen(F[k-2], k) # generate candidate itemsets
        Fk, supK = support_prune(D, Ck, min_support) # prune candidate itemsets
        support_data.update(supK) # update the support counts to reflect pruning
        F.append(Fk) # add the pruned candidate itemsets to the list of frequent itemsets
        k += 1

    if verbose:
        # Print a list of all the frequent itemsets.
        for kset in F:
            for item in kset:
                print("" \
                    + "{" \
                    + "".join(str(i) + ", " for i in iter(item)).rstrip(', ') \
                    + "}" \
                    + ":  sup = " + str(round(support_data[item], 3)))

    return F, support_data

def create_candidates(dataset, verbose=False):
    """Creates a list of candidate 1-itemsets from a list of transactions.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate candidate 
        itemsets.

    Returns
    -------
    The list of candidate itemsets (c1) passed as a frozenset (a set that is 
    immutable and hashable).
    """
    c1 = [] # list of all items in the database of transactions
    for transaction in dataset:
        for item in transaction:
            if not [item] in c1:
                c1.append([item])
    c1.sort()

    if verbose:
        # Print a list of all the candidate items.
        print("" \
            + "{" \
            + "".join(str(i[0]) + ", " for i in iter(c1)).rstrip(', ') \
            + "}")

    # Map c1 to a frozenset because it will be the key of a dictionary.
    return list(map(frozenset, c1))

def support_prune(dataset, candidates, min_support, verbose=False):
    """Returns all candidate itemsets that meet a minimum support threshold.

    By the apriori principle, if an itemset is frequent, then all of its 
    subsets must also be frequent. As a result, we can perform support-based 
    pruning to systematically control the exponential growth of candidate 
    itemsets. Thus, itemsets that do not meet the minimum support level are 
    pruned from the input list of itemsets (dataset).

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate candidate 
        itemsets.

    candidates : frozenset
        The list of candidate itemsets.

    min_support : float
        The minimum support threshold.

    Returns
    -------
    retlist : list
        The list of frequent itemsets.

    support_data : dict
        The support data for all candidate itemsets.
    """
    sscnt = {} # set for support counts
    for tid in dataset:
        for can in candidates:
            if can.issubset(tid):
                sscnt.setdefault(can, 0)
                sscnt[can] += 1

    num_items = float(len(dataset)) # total number of transactions in the dataset
    retlist = [] # array for unpruned itemsets
    support_data = {} # set for support data for corresponding itemsets
    for key in sscnt:
        # Calculate the support of itemset key.
        support = sscnt[key] / num_items
        if support >= min_support:
            retlist.insert(0, key)
        support_data[key] = support

    # Print a list of the pruned itemsets.
    if verbose:
        for kset in retlist:
            for item in kset:
                print("{" + str(item) + "}")
        print("")
        for key in sscnt:
            print("" \
                + "{" \
                + "".join([str(i) + ", " for i in iter(key)]).rstrip(', ') \
                + "}" \
                + ":  sup = " + str(support_data[key]))

    return retlist, support_data

def apriori_gen(freq_sets, k):
    """Generates candidate itemsets (via the F_k-1 x F_k-1 method).

    This operation generates new candidate k-itemsets based on the frequent 
    (k-1)-itemsets found in the previous iteration. The candidate generation 
    procedure merges a pair of frequent (k-1)-itemsets only if their first k-2 
    items are identical.

    Parameters
    ----------
    freq_sets : list
        The list of frequent (k-1)-itemsets.

    k : integer
        The cardinality of the current itemsets being evaluated.

    Returns
    -------
    retlist : list
        The list of merged frequent itemsets.
    """
    retList = [] # list of merged frequent itemsets
    lenLk = len(freq_sets) # number of frequent itemsets
    for i in range(lenLk):
        for j in range(i+1, lenLk):
            a=list(freq_sets[i])
            b=list(freq_sets[j])
            a.sort()
            b.sort()
            F1 = a[:k-2] # first k-2 items of freq_sets[i]
            F2 = b[:k-2] # first k-2 items of freq_sets[j]

            if F1 == F2: # if the first k-2 items are identical
                # Merge the frequent itemsets.
                retList.append(freq_sets[i] | freq_sets[j])

    return retList

def rules_from_conseq(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Generates a set of candidate rules.

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    support_data : dict
        The support data for all candidate itemsets.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.
    """
    m = len(H[0])
    if m == 1:
        Hmp1 = calc_confidence(freq_set, H, support_data, rules, min_confidence, verbose)
    if (len(freq_set) > (m+1)):
        Hmp1 = apriori_gen(H, m+1) # generate candidate itemsets
        Hmp1 = calc_confidence(freq_set, Hmp1, support_data, rules, min_confidence, verbose)
        if len(Hmp1) > 1:
            # If there are candidate rules above the minimum confidence 
            # threshold, recurse on the list of these candidate rules.
            rules_from_conseq(freq_set, Hmp1, support_data, rules, min_confidence, verbose)

def calc_confidence(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Evaluates the generated rules.

    One measurement for quantifying the goodness of association rules is 
    confidence. The confidence for a rule 'P implies H' (P -> H) is defined as 
    the support for P and H divided by the support for P 
    (support (P|H) / support(P)), where the | symbol denotes the set union 
    (thus P|H means all the items in set P or in set H).

    To calculate the confidence, we iterate through the frequent itemsets and 
    associated support data. For each frequent itemset, we divide the support 
    of the itemset by the support of the antecedent (left-hand-side of the 
    rule).

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    min_support : float
        The minimum support threshold.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    pruned_H : list
        The list of candidate rules above the minimum confidence threshold.
    """
    pruned_H = [] # list of candidate rules above the minimum confidence threshold
    for conseq in H: # iterate over the frequent itemsets
        conf = support_data[freq_set] / support_data[freq_set - conseq]
        if conf >= min_confidence:
            rules.append((freq_set - conseq, conseq, conf))
            pruned_H.append(conseq)

            if verbose:
                print("" \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(freq_set-conseq)]).rstrip(', ') \
                    + "}" \
                    + " ---> " \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(conseq)]).rstrip(', ') \
                    + "}" \
                    + ":  conf = " + str(round(conf, 3)) \
                    + ", sup = " + str(round(support_data[freq_set], 3)))

    return pruned_H

def generate_rules(F, support_data, min_confidence=0.5, verbose=True):
    """Generates a set of candidate rules from a list of frequent itemsets.

    For each frequent itemset, we calculate the confidence of using a
    particular item as the rule consequent (right-hand-side of the rule). By 
    testing and merging the remaining rules, we recursively create a list of 
    pruned rules.

    Parameters
    ----------
    F : list
        A list of frequent itemsets.

    support_data : dict
        The corresponding support data for the frequent itemsets (L).

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    rules : list
        The list of candidate rules above the minimum confidence threshold.
    """
    rules = []
    for i in range(1, len(F)):
        for freq_set in F[i]:
            H1 = [frozenset([itemset]) for itemset in freq_set]
            if (i > 1):
                rules_from_conseq(freq_set, H1, support_data, rules, min_confidence, verbose)
            else:
                calc_confidence(freq_set, H1, support_data, rules, min_confidence, verbose)

    return rules

# (c) 2014 Reid Johnson
#
# Modified from:
# Eric Naeseth <eric@naeseth.com>
# (https://github.com/enaeseth/python-fp-growth/blob/master/fp_growth.py)
#
# A Python implementation of the FP-growth algorithm.

from collections import defaultdict, namedtuple
#from itertools import imap

__author__ = 'Eric Naeseth <eric@naeseth.com>'
__copyright__ = 'Copyright © 2009 Eric Naeseth'
__license__ = 'MIT License'

def fpgrowth(dataset, min_support=0.5, include_support=True, verbose=False):
    """Implements the FP-growth algorithm.

    The `dataset` parameter can be any iterable of iterables of items.
    `min_support` should be an integer specifying the minimum number of
    occurrences of an itemset for it to be accepted.

    Each item must be hashable (i.e., it must be valid as a member of a
    dictionary or a set).

    If `include_support` is true, yield (itemset, support) pairs instead of
    just the itemsets.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate 
        candidate itemsets.

    min_support : float
        The minimum support threshold. Defaults to 0.5.

    include_support : bool
        Include support in output (default=False).

    References
    ----------
    .. [1] J. Han, J. Pei, Y. Yin, "Mining Frequent Patterns without Candidate 
           Generation," 2000.

    """

    F = []
    support_data = {}
    for k,v in find_frequent_itemsets(dataset, min_support=min_support, include_support=include_support, verbose=verbose):
        F.append(frozenset(k))
        support_data[frozenset(k)] = v

    # Create one array with subarrays that hold all transactions of equal length.
    def bucket_list(nested_list, sort=True):
        bucket = defaultdict(list)
        for sublist in nested_list:
            bucket[len(sublist)].append(sublist)
        return [v for k,v in sorted(bucket.items())] if sort else bucket.values()

    F = bucket_list(F)
    
    return F, support_data

def find_frequent_itemsets(dataset, min_support, include_support=False, verbose=False):
    """
    Find frequent itemsets in the given transactions using FP-growth. This
    function returns a generator instead of an eagerly-populated list of items.

    The `dataset` parameter can be any iterable of iterables of items.
    `min_support` should be an integer specifying the minimum number of
    occurrences of an itemset for it to be accepted.

    Each item must be hashable (i.e., it must be valid as a member of a
    dictionary or a set).

    If `include_support` is true, yield (itemset, support) pairs instead of
    just the itemsets.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate 
        candidate itemsets.

    min_support : float
        The minimum support threshold. Defaults to 0.5.

    include_support : bool
        Include support in output (default=False).

    """
    items = defaultdict(lambda: 0) # mapping from items to their supports
    processed_transactions = []

    # Load the passed-in transactions and count the support that individual
    # items have.
    for transaction in dataset:
        processed = []
        for item in transaction:
            items[item] += 1
            processed.append(item)
        processed_transactions.append(processed)

    # Remove infrequent items from the item support dictionary.
    items = dict((item, support) for item, support in items.items()
        if support >= min_support)

    # Build our FP-tree. Before any transactions can be added to the tree, they
    # must be stripped of infrequent items and their surviving items must be
    # sorted in decreasing order of frequency.
    def clean_transaction(transaction):
        #transaction = filter(lambda v: v in items, transaction)
        transaction.sort(key=lambda v: items[v], reverse=True)
        return transaction

    master = FPTree()
    for transaction in map(clean_transaction, processed_transactions):
        master.add(transaction)

    support_data = {}
    def find_with_suffix(tree, suffix):
        for item, nodes in tree.items():
            support = float(sum(n.count for n in nodes)) / len(dataset)
            if support >= min_support and item not in suffix:
                # New winner!
                found_set = [item] + suffix
                support_data[frozenset(found_set)] = support
                yield (found_set, support) if include_support else found_set

                # Build a conditional tree and recursively search for frequent
                # itemsets within it.
                cond_tree = conditional_tree_from_paths(tree.prefix_paths(item),
                    min_support)
                for s in find_with_suffix(cond_tree, found_set):
                    yield s # pass along the good news to our caller

    if verbose:
        # Print a list of all the frequent itemsets.
        for itemset, support in find_with_suffix(master, []):
            print("" \
                + "{" \
                + "".join(str(i) + ", " for i in iter(itemset)).rstrip(', ') \
                + "}" \
                + ":  sup = " + str(round(support_data[frozenset(itemset)], 3)))

    # Search for frequent itemsets, and yield the results we find.
    for itemset in find_with_suffix(master, []):
        yield itemset

class FPTree(object):
    """
    An FP tree.

    This object may only store transaction items that are hashable (i.e., all
    items must be valid as dictionary keys or set members).
    """

    Route = namedtuple('Route', 'head tail')

    def __init__(self):
        # The root node of the tree.
        self._root = FPNode(self, None, None)

        # A dictionary mapping items to the head and tail of a path of
        # "neighbors" that will hit every node containing that item.
        self._routes = {}

    @property
    def root(self):
        """The root node of the tree."""
        return self._root

    def add(self, transaction):
        """
        Adds a transaction to the tree.
        """

        point = self._root

        for item in transaction:
            next_point = point.search(item)
            if next_point:
                # There is already a node in this tree for the current
                # transaction item; reuse it.
                next_point.increment()
            else:
                # Create a new point and add it as a child of the point we're
                # currently looking at.
                next_point = FPNode(self, item)
                point.add(next_point)

                # Update the route of nodes that contain this item to include
                # our new node.
                self._update_route(next_point)

            point = next_point

    def _update_route(self, point):
        """Add the given node to the route through all nodes for its item."""
        assert self is point.tree

        try:
            route = self._routes[point.item]
            route[1].neighbor = point # route[1] is the tail
            self._routes[point.item] = self.Route(route[0], point)
        except KeyError:
            # First node for this item; start a new route.
            self._routes[point.item] = self.Route(point, point)

    def items(self):
        """
        Generate one 2-tuples for each item represented in the tree. The first
        element of the tuple is the item itself, and the second element is a
        generator that will yield the nodes in the tree that belong to the item.
        """
        for item in self._routes.keys():
            yield (item, self.nodes(item))

            
    def nodes(self, item):
        """
        Generates the sequence of nodes that contain the given item.
        """

        try:
            node = self._routes[item][0]
        except KeyError:
            return

        while node:
            yield node
            node = node.neighbor

    def prefix_paths(self, item):
        """Generates the prefix paths that end with the given item."""

        def collect_path(node):
            path = []
            while node and not node.root:
                path.append(node)
                node = node.parent
            path.reverse()
            return path

        return (collect_path(node) for node in self.nodes(item))

    def inspect(self):
        print("Tree:")
        self.root.inspect(1)

        print("")
        print("Routes:")
        for item, nodes in self.items():
            print("  %r" % item)
            for node in nodes:
                print("    %r" % node)

    def _removed(self, node):
        """Called when `node` is removed from the tree; performs cleanup."""

        head, tail = self._routes[node.item]
        if node is head:
            if node is tail or not node.neighbor:
                # It was the sole node.
                del self._routes[node.item]
            else:
                self._routes[node.item] = self.Route(node.neighbor, tail)
        else:
            for n in self.nodes(node.item):
                if n.neighbor is node:
                    n.neighbor = node.neighbor # skip over
                    if node is tail:
                        self._routes[node.item] = self.Route(head, n)
                    break

def conditional_tree_from_paths(paths, min_support):
    """Builds a conditional FP-tree from the given prefix paths."""
    tree = FPTree()
    condition_item = None
    items = set()

    # Import the nodes in the paths into the new tree. Only the counts of the
    # leaf notes matter; the remaining counts will be reconstructed from the
    # leaf counts.
    for path in paths:
        if condition_item is None:
            condition_item = path[-1].item

        point = tree.root
        for node in path:
            next_point = point.search(node.item)
            if not next_point:
                # Add a new node to the tree.
                items.add(node.item)
                count = node.count if node.item == condition_item else 0
                next_point = FPNode(tree, node.item, count)
                point.add(next_point)
                tree._update_route(next_point)
            point = next_point

    assert condition_item is not None

    # Calculate the counts of the non-leaf nodes.
    for path in tree.prefix_paths(condition_item):
        count = path[-1].count
        for node in reversed(path[:-1]):
            node._count += count

    # Eliminate the nodes for any items that are no longer frequent.
    for item in items:
        support = sum(n.count for n in tree.nodes(item))
        if support < min_support:
            # Doesn't make the cut anymore
            for node in tree.nodes(item):
                if node.parent is not None:
                    node.parent.remove(node)

    # Finally, remove the nodes corresponding to the item for which this
    # conditional tree was generated.
    for node in tree.nodes(condition_item):
        if node.parent is not None: # the node might already be an orphan
            node.parent.remove(node)

    return tree

class FPNode(object):
    """A node in an FP tree."""

    def __init__(self, tree, item, count=1):
        self._tree = tree
        self._item = item
        self._count = count
        self._parent = None
        self._children = {}
        self._neighbor = None

    def add(self, child):
        """Adds the given FPNode `child` as a child of this node."""

        if not isinstance(child, FPNode):
            raise TypeError("Can only add other FPNodes as children")

        if not child.item in self._children:
            self._children[child.item] = child
            child.parent = self

    def search(self, item):
        """
        Checks to see if this node contains a child node for the given item.
        If so, that node is returned; otherwise, `None` is returned.
        """

        try:
            return self._children[item]
        except KeyError:
            return None

    def remove(self, child):
        try:
            if self._children[child.item] is child:
                del self._children[child.item]
                child.parent = None
                self._tree._removed(child)
                for sub_child in child.children:
                    try:
                        # Merger case: we already have a child for that item, so
                        # add the sub-child's count to our child's count.
                        self._children[sub_child.item]._count += sub_child.count
                        sub_child.parent = None # it's an orphan now
                    except KeyError:
                        # Turns out we don't actually have a child, so just add
                        # the sub-child as our own child.
                        self.add(sub_child)
                child._children = {}
            else:
                raise ValueError("that node is not a child of this node")
        except KeyError:
            raise ValueError("that node is not a child of this node")

    def __contains__(self, item):
        return item in self._children

    @property
    def tree(self):
        """The tree in which this node appears."""
        return self._tree

    @property
    def item(self):
        """The item contained in this node."""
        return self._item

    @property
    def count(self):
        """The count associated with this node's item."""
        return self._count

    def increment(self):
        """Increments the count associated with this node's item."""
        if self._count is None:
            raise ValueError("Root nodes have no associated count.")
        self._count += 1

    @property
    def root(self):
        """True if this node is the root of a tree; false if otherwise."""
        return self._item is None and self._count is None

    @property
    def leaf(self):
        """True if this node is a leaf in the tree; false if otherwise."""
        return len(self._children) == 0

    def parent():
        doc = "The node's parent."
        def fget(self):
            return self._parent
        def fset(self, value):
            if value is not None and not isinstance(value, FPNode):
                raise TypeError("A node must have an FPNode as a parent.")
            if value and value.tree is not self.tree:
                raise ValueError("Cannot have a parent from another tree.")
            self._parent = value
        return locals()
    parent = property(**parent())

    def neighbor():
        doc = """
        The node's neighbor; the one with the same value that is "to the right"
        of it in the tree.
        """
        def fget(self):
            return self._neighbor
        def fset(self, value):
            if value is not None and not isinstance(value, FPNode):
                raise TypeError("A node must have an FPNode as a neighbor.")
            if value and value.tree is not self.tree:
                raise ValueError("Cannot have a neighbor from another tree.")
            self._neighbor = value
        return locals()
    neighbor = property(**neighbor())

    @property
    def children(self):
        """The nodes that are children of this node."""
        return tuple(self._children.values())
        
    def inspect(self, depth=0):
        print(('  ' * depth) + repr(self))
        for child in self.children:
            child.inspect(depth + 1)

    def __repr__(self):
        if self.root:
            return "<%s (root)>" % type(self).__name__
        return "<%s %r (%r)>" % (type(self).__name__, self.item, self.count)

def rules_from_conseq(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Generates a set of candidate rules.

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    support_data : dict
        The support data for all candidate itemsets.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.
    """
    m = len(H[0])
    if m == 1:
        Hmp1 = calc_confidence(freq_set, H, support_data, rules, min_confidence, verbose)
    if (len(freq_set) > (m+1)):
        Hmp1 = apriori_gen(H, m+1) # generate candidate itemsets
        Hmp1 = calc_confidence(freq_set, Hmp1,  support_data, rules, min_confidence, verbose)
        if len(Hmp1) > 1:
            # If there are candidate rules above the minimum confidence 
            # threshold, recurse on the list of these candidate rules.
            rules_from_conseq(freq_set, Hmp1, support_data, rules, min_confidence, verbose)

def calc_confidence(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Evaluates the generated rules.

    One measurement for quantifying the goodness of association rules is 
    confidence. The confidence for a rule 'P implies H' (P -> H) is defined as 
    the support for P and H divided by the support for P 
    (support (P|H) / support(P)), where the | symbol denotes the set union 
    (thus P|H means all the items in set P or in set H).

    To calculate the confidence, we iterate through the frequent itemsets and 
    associated support data. For each frequent itemset, we divide the support 
    of the itemset by the support of the antecedent (left-hand-side of the 
    rule).

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    min_support : float
        The minimum support threshold.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    pruned_H : list
        The list of candidate rules above the minimum confidence threshold.
    """
    pruned_H = [] # list of candidate rules above the minimum confidence threshold
    for conseq in H: # iterate over the frequent itemsets
        conf = support_data[freq_set] / support_data[freq_set - conseq]
        if conf >= min_confidence:
            rules.append((freq_set - conseq, conseq, conf))
            pruned_H.append(conseq)

            if verbose:
                print("" \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(freq_set-conseq)]).rstrip(', ') \
                    + "}" \
                    + " ---> " \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(conseq)]).rstrip(', ') \
                    + "}" \
                    + ":  conf = " + str(round(conf, 3)) \
                    + ", sup = " + str(round(support_data[freq_set], 3)))

    return pruned_H

def generate_rules(F, support_data, min_confidence=0.5, verbose=True):
    """Generates a set of candidate rules from a list of frequent itemsets.

    For each frequent itemset, we calculate the confidence of using a
    particular item as the rule consequent (right-hand-side of the rule). By 
    testing and merging the remaining rules, we recursively create a list of 
    pruned rules.

    Parameters
    ----------
    F : list
        A list of frequent itemsets.

    support_data : dict
        The corresponding support data for the frequent itemsets (L).

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    rules : list
        The list of candidate rules above the minimum confidence threshold.
    """
    rules = []
    for i in range(1, len(F)):
        for freq_set in F[i]:
            H1 = [frozenset([item]) for item in freq_set]
            if (i > 1):
                rules_from_conseq(freq_set, H1, support_data, rules, min_confidence, verbose)
            else:
                calc_confidence(freq_set, H1, support_data, rules, min_confidence, verbose)

    return rules

# %% [markdown]
# ### To load our dataset of grocery transactions, use the command below

# %%
dataset = load_dataset('grocery.csv')

# %% [markdown]
# ## Part 1: Apriori algorithm

# %%
# Generate all the frequent itemsets using the Apriori algorithm.
F, support_data = apriori(dataset, min_support=0.005, verbose=True)
# Out:
# {pip fruit}:  sup = 0.076
# {pickled vegetables}:  sup = 0.018
# {berries}:  sup = 0.033
# {softener}:  sup = 0.005
# {cream cheese}:  sup = 0.04
# {napkins}:  sup = 0.052
# {pet care}:  sup = 0.009
# {specialty bar}:  sup = 0.027
# {detergent}:  sup = 0.019
# {bottled water}:  sup = 0.111
# {spices}:  sup = 0.005
# {soda}:  sup = 0.174
# {hard cheese}:  sup = 0.025
# {liquor}:  sup = 0.011
# {whole milk}:  sup = 0.256
# {frankfurter}:  sup = 0.059
# {beef}:  sup = 0.052
# {meat}:  sup = 0.026
# {female sanitary products}:  sup = 0.006
# {spread cheese}:  sup = 0.011
# {zwieback}:  sup = 0.007
# {misc. beverages}:  sup = 0.028
# {coffee}:  sup = 0.058
# {chicken}:  sup = 0.043
# {dental care}:  sup = 0.006
# {semi-finished bread}:  sup = 0.018
# {red/blush wine}:  sup = 0.019
# {frozen fish}:  sup = 0.012
# {dish cleaner}:  sup = 0.01
# {house keeping products}:  sup = 0.008
# {citrus fruit}:  sup = 0.083
# {salty snack}:  sup = 0.038
# {dessert}:  sup = 0.037
# {condensed milk}:  sup = 0.01
# {kitchen towels}:  sup = 0.006
# {frozen dessert}:  sup = 0.011
# {oil}:  sup = 0.028
# {specialty cheese}:  sup = 0.009
# {jam}:  sup = 0.005
# {turkey}:  sup = 0.008
# {Instant food products}:  sup = 0.008
# {dishes}:  sup = 0.018
# {mayonnaise}:  sup = 0.009
# {cake bar}:  sup = 0.013
# {pot plants}:  sup = 0.017
# {liquor (appetizer)}:  sup = 0.008
# {dog food}:  sup = 0.009
# {popcorn}:  sup = 0.007
# {frozen meals}:  sup = 0.028
# {curd cheese}:  sup = 0.005
# {frozen vegetables}:  sup = 0.048
# {herbs}:  sup = 0.016
# {flour}:  sup = 0.017
# {root vegetables}:  sup = 0.109
# {fruit/vegetable juice}:  sup = 0.072
# {salt}:  sup = 0.011
# {curd}:  sup = 0.053
# {white bread}:  sup = 0.042
# {liver loaf}:  sup = 0.005
# {whipped/sour cream}:  sup = 0.072
# {vinegar}:  sup = 0.007
# {cleaner}:  sup = 0.005
# {sausage}:  sup = 0.094
# {baking powder}:  sup = 0.018
# {grapes}:  sup = 0.022
# {ham}:  sup = 0.026
# {instant coffee}:  sup = 0.007
# {butter milk}:  sup = 0.028
# {chocolate}:  sup = 0.05
# {yogurt}:  sup = 0.14
# {frozen potato products}:  sup = 0.008
# {other vegetables}:  sup = 0.193
# {cereals}:  sup = 0.006
# {butter}:  sup = 0.055
# {newspapers}:  sup = 0.08
# {bottled beer}:  sup = 0.081
# {mustard}:  sup = 0.012
# {canned fish}:  sup = 0.015
# {seasonal products}:  sup = 0.014
# {sugar}:  sup = 0.034
# {roll products}:  sup = 0.01
# {chocolate marshmallow}:  sup = 0.009
# {waffles}:  sup = 0.038
# {chewing gum}:  sup = 0.021
# {pasta}:  sup = 0.015
# {candy}:  sup = 0.03
# {hygiene articles}:  sup = 0.033
# {flower (seeds)}:  sup = 0.01
# {sweet spreads}:  sup = 0.009
# {soft cheese}:  sup = 0.017
# {candles}:  sup = 0.009
# {ice cream}:  sup = 0.025
# {rolls/buns}:  sup = 0.184
# {shopping bags}:  sup = 0.099
# {photo/film}:  sup = 0.009
# {pork}:  sup = 0.058
# {tropical fruit}:  sup = 0.105
# {packaged fruit/vegetables}:  sup = 0.013
# {sauces}:  sup = 0.005
# {soups}:  sup = 0.007
# {cling film/bags}:  sup = 0.011
# {sliced cheese}:  sup = 0.025
# {margarine}:  sup = 0.059
# {UHT-milk}:  sup = 0.033
# {white wine}:  sup = 0.019
# {canned beer}:  sup = 0.078
# {brown bread}:  sup = 0.065
# {pastry}:  sup = 0.089
# {rice}:  sup = 0.008
# {beverages}:  sup = 0.026
# {long life bakery product}:  sup = 0.037
# {hamburger meat}:  sup = 0.033
# {canned vegetables}:  sup = 0.011
# {processed cheese}:  sup = 0.017
# {onions}:  sup = 0.031
# {specialty chocolate}:  sup = 0.03
# {domestic eggs}:  sup = 0.063
# {sparkling wine}:  sup = 0.006
# {cat food}:  sup = 0.023
# {finished products}:  sup = 0.007
# {pickled vegetables, whole milk}:  sup = 0.007
# {shopping bags, whole milk}:  sup = 0.025
# {whole milk, tropical fruit}:  sup = 0.042
# {tropical fruit, curd}:  sup = 0.01
# {yogurt, chocolate}:  sup = 0.009
# {dessert, bottled water}:  sup = 0.005
# {baking powder, other vegetables}:  sup = 0.007
# {root vegetables, pastry}:  sup = 0.011
# {grapes, tropical fruit}:  sup = 0.006
# {soda, meat}:  sup = 0.005
# {white bread, frankfurter}:  sup = 0.005
# {root vegetables, beef}:  sup = 0.017
# {rolls/buns, chicken}:  sup = 0.01
# {whole milk, herbs}:  sup = 0.008
# {whole milk, butter milk}:  sup = 0.012
# {pork, beef}:  sup = 0.008
# {rolls/buns, meat}:  sup = 0.007
# {shopping bags, sausage}:  sup = 0.016
# {soft cheese, rolls/buns}:  sup = 0.005
# {sugar, pastry}:  sup = 0.005
# {bottled beer, tropical fruit}:  sup = 0.008
# {sausage, butter}:  sup = 0.009
# {fruit/vegetable juice, bottled beer}:  sup = 0.007
# {frankfurter, other vegetables}:  sup = 0.016
# {dessert, soda}:  sup = 0.01
# {yogurt, rolls/buns}:  sup = 0.034
# {tropical fruit, pastry}:  sup = 0.013
# {shopping bags, hygiene articles}:  sup = 0.005
# {brown bread, bottled water}:  sup = 0.008
# {root vegetables, rolls/buns}:  sup = 0.024
# {dessert, rolls/buns}:  sup = 0.007
# {chocolate, soda}:  sup = 0.014
# {bottled water, rolls/buns}:  sup = 0.024
# {yogurt, bottled beer}:  sup = 0.009
# {sausage, bottled water}:  sup = 0.012
# {bottled beer, bottled water}:  sup = 0.016
# {other vegetables, meat}:  sup = 0.01
# {brown bread, butter}:  sup = 0.006
# {white bread, rolls/buns}:  sup = 0.007
# {other vegetables, soda}:  sup = 0.033
# {frozen vegetables, whipped/sour cream}:  sup = 0.008
# {waffles, soda}:  sup = 0.01
# {citrus fruit, tropical fruit}:  sup = 0.02
# {dessert, yogurt}:  sup = 0.01
# {other vegetables, flour}:  sup = 0.006
# {sausage, yogurt}:  sup = 0.02
# {rolls/buns, pastry}:  sup = 0.021
# {tropical fruit, butter milk}:  sup = 0.005
# {other vegetables, brown bread}:  sup = 0.019
# {frankfurter, tropical fruit}:  sup = 0.009
# {newspapers, brown bread}:  sup = 0.008
# {cream cheese , whipped/sour cream}:  sup = 0.006
# {ham, rolls/buns}:  sup = 0.007
# {soft cheese, whole milk}:  sup = 0.008
# {domestic eggs, frozen vegetables}:  sup = 0.005
# {whole milk, meat}:  sup = 0.01
# {root vegetables, other vegetables}:  sup = 0.047
# {rolls/buns, butter milk}:  sup = 0.008
# {white bread, tropical fruit}:  sup = 0.009
# {whole milk, cake bar}:  sup = 0.006
# {whole milk, grapes}:  sup = 0.007
# {pip fruit, margarine}:  sup = 0.009
# {sausage, frozen vegetables}:  sup = 0.006
# {beverages, other vegetables}:  sup = 0.005
# {berries, soda}:  sup = 0.007
# {whole milk, butter}:  sup = 0.028
# {whole milk, canned beer}:  sup = 0.009
# {sausage, whole milk}:  sup = 0.03
# {pip fruit, curd}:  sup = 0.008
# {yogurt, brown bread}:  sup = 0.015
# {domestic eggs, brown bread}:  sup = 0.007
# {frankfurter, coffee}:  sup = 0.005
# {frankfurter, citrus fruit}:  sup = 0.007
# {soda, salty snack}:  sup = 0.009
# {soda, beef}:  sup = 0.008
# {shopping bags, long life bakery product}:  sup = 0.005
# {dessert, sausage}:  sup = 0.006
# {dessert, other vegetables}:  sup = 0.012
# {frankfurter, domestic eggs}:  sup = 0.007
# {frankfurter, soda}:  sup = 0.011
# {root vegetables, citrus fruit}:  sup = 0.018
# {whole milk, chewing gum}:  sup = 0.005
# {yogurt, soda}:  sup = 0.027
# {margarine, soda}:  sup = 0.01
# {yogurt, cat food}:  sup = 0.006
# {pastry, pork}:  sup = 0.006
# {whipped/sour cream, coffee}:  sup = 0.006
# {pip fruit, root vegetables}:  sup = 0.016
# {sausage, cream cheese}:  sup = 0.006
# {yogurt, citrus fruit}:  sup = 0.022
# {whole milk, cat food}:  sup = 0.009
# {root vegetables, butter milk}:  sup = 0.005
# {whole milk, coffee}:  sup = 0.019
# {whole milk, semi-finished bread}:  sup = 0.007
# {other vegetables, pastry}:  sup = 0.023
# {bottled water, margarine}:  sup = 0.01
# {sausage, chicken}:  sup = 0.005
# {shopping bags, pork}:  sup = 0.006
# {hygiene articles, napkins}:  sup = 0.006
# {whipped/sour cream, citrus fruit}:  sup = 0.011
# {fruit/vegetable juice, napkins}:  sup = 0.007
# {brown bread, soda}:  sup = 0.013
# {whole milk, hamburger meat}:  sup = 0.015
# {butter, chicken}:  sup = 0.006
# {newspapers, tropical fruit}:  sup = 0.012
# {fruit/vegetable juice, coffee}:  sup = 0.006
# {sausage, citrus fruit}:  sup = 0.011
# {yogurt, tropical fruit}:  sup = 0.029
# {whole milk, curd}:  sup = 0.026
# {dessert, tropical fruit}:  sup = 0.006
# {newspapers, margarine}:  sup = 0.007
# {sausage, brown bread}:  sup = 0.011
# {shopping bags, whipped/sour cream}:  sup = 0.008
# {newspapers, pork}:  sup = 0.007
# {citrus fruit, curd}:  sup = 0.007
# {shopping bags, pip fruit}:  sup = 0.009
# {pastry, salty snack}:  sup = 0.005
# {napkins, whipped/sour cream}:  sup = 0.007
# {fruit/vegetable juice, chocolate}:  sup = 0.007
# {yogurt, fruit/vegetable juice}:  sup = 0.019
# {root vegetables, hygiene articles}:  sup = 0.005
# {frozen vegetables, tropical fruit}:  sup = 0.009
# {sausage, newspapers}:  sup = 0.008
# {yogurt, hamburger meat}:  sup = 0.007
# {white bread, soda}:  sup = 0.01
# {sausage, napkins}:  sup = 0.007
# {waffles, tropical fruit}:  sup = 0.006
# {root vegetables, white bread}:  sup = 0.008
# {other vegetables, herbs}:  sup = 0.008
# {fruit/vegetable juice, soda}:  sup = 0.018
# {margarine, beef}:  sup = 0.006
# {yogurt, beef}:  sup = 0.012
# {yogurt, salty snack}:  sup = 0.006
# {ham, whole milk}:  sup = 0.011
# {baking powder, whole milk}:  sup = 0.009
# {berries, whole milk}:  sup = 0.012
# {domestic eggs, beef}:  sup = 0.006
# {fruit/vegetable juice, long life bakery product}:  sup = 0.006
# {butter, beef}:  sup = 0.006
# {whole milk, misc. beverages}:  sup = 0.007
# {sausage, whipped/sour cream}:  sup = 0.009
# {sliced cheese, soda}:  sup = 0.005
# {sausage, meat}:  sup = 0.005
# {dessert, whole milk}:  sup = 0.014
# {whipped/sour cream, beef}:  sup = 0.007
# {candy, other vegetables}:  sup = 0.007
# {fruit/vegetable juice, citrus fruit}:  sup = 0.01
# {other vegetables, margarine}:  sup = 0.02
# {white bread, whole milk}:  sup = 0.017
# {sausage, beef}:  sup = 0.006
# {rolls/buns, hard cheese}:  sup = 0.006
# {other vegetables, salty snack}:  sup = 0.011
# {curd, rolls/buns}:  sup = 0.01
# {domestic eggs, tropical fruit}:  sup = 0.011
# {napkins, bottled water}:  sup = 0.009
# {berries, tropical fruit}:  sup = 0.007
# {whole milk, mustard}:  sup = 0.005
# {newspapers, beef}:  sup = 0.006
# {other vegetables, butter}:  sup = 0.02
# {sausage, canned beer}:  sup = 0.006
# {pip fruit, whole milk}:  sup = 0.03
# {other vegetables, whipped/sour cream}:  sup = 0.029
# {waffles, rolls/buns}:  sup = 0.009
# {shopping bags, frankfurter}:  sup = 0.008
# {cream cheese , bottled water}:  sup = 0.006
# {sliced cheese, rolls/buns}:  sup = 0.008
# {newspapers, citrus fruit}:  sup = 0.008
# {yogurt, butter}:  sup = 0.015
# {citrus fruit, pastry}:  sup = 0.01
# {whipped/sour cream, rolls/buns}:  sup = 0.015
# {bottled water, pork}:  sup = 0.007
# {fruit/vegetable juice, whipped/sour cream}:  sup = 0.009
# {whole milk, pastry}:  sup = 0.033
# {frankfurter, brown bread}:  sup = 0.007
# {domestic eggs, pork}:  sup = 0.006
# {whole milk, margarine}:  sup = 0.024
# {yogurt, canned beer}:  sup = 0.005
# {whole milk, hard cheese}:  sup = 0.01
# {sliced cheese, tropical fruit}:  sup = 0.005
# {frozen vegetables, margarine}:  sup = 0.005
# {long life bakery product, rolls/buns}:  sup = 0.008
# {sausage, pastry}:  sup = 0.013
# {fruit/vegetable juice, brown bread}:  sup = 0.008
# {bottled water, whipped/sour cream}:  sup = 0.009
# {other vegetables, ice cream}:  sup = 0.005
# {newspapers, chicken}:  sup = 0.005
# {pip fruit, white bread}:  sup = 0.007
# {white bread, yogurt}:  sup = 0.009
# {shopping bags, bottled water}:  sup = 0.011
# {UHT-milk, soda}:  sup = 0.008
# {domestic eggs, soda}:  sup = 0.012
# {whipped/sour cream, pastry}:  sup = 0.008
# {shopping bags, coffee}:  sup = 0.009
# {margarine, whipped/sour cream}:  sup = 0.007
# {bottled water, soda}:  sup = 0.029
# {soda, coffee}:  sup = 0.01
# {canned beer, soda}:  sup = 0.014
# {newspapers, fruit/vegetable juice}:  sup = 0.008
# {domestic eggs, citrus fruit}:  sup = 0.01
# {yogurt, newspapers}:  sup = 0.015
# {butter, pastry}:  sup = 0.008
# {frozen vegetables, pork}:  sup = 0.006
# {root vegetables, soda}:  sup = 0.019
# {brown bread, tropical fruit}:  sup = 0.011
# {citrus fruit, coffee}:  sup = 0.006
# {canned beer, rolls/buns}:  sup = 0.011
# {citrus fruit, pork}:  sup = 0.007
# {root vegetables, brown bread}:  sup = 0.01
# {shopping bags, bottled beer}:  sup = 0.006
# {citrus fruit, butter}:  sup = 0.009
# {dishes, other vegetables}:  sup = 0.006
# {whole milk, specialty chocolate}:  sup = 0.008
# {root vegetables, margarine}:  sup = 0.011
# {pastry, coffee}:  sup = 0.007
# {yogurt, margarine}:  sup = 0.014
# {yogurt, butter milk}:  sup = 0.009
# {rolls/buns, specialty chocolate}:  sup = 0.006
# {other vegetables, hard cheese}:  sup = 0.009
# {cream cheese , citrus fruit}:  sup = 0.006
# {other vegetables, semi-finished bread}:  sup = 0.005
# {bottled water, misc. beverages}:  sup = 0.005
# {pip fruit, cream cheese}:  sup = 0.006
# {other vegetables, rolls/buns}:  sup = 0.043
# {hygiene articles, bottled water}:  sup = 0.006
# {cream cheese , soda}:  sup = 0.007
# {yogurt, frankfurter}:  sup = 0.011
# {whole milk, rolls/buns}:  sup = 0.057
# {oil, other vegetables}:  sup = 0.01
# {dishes, whole milk}:  sup = 0.005
# {whipped/sour cream, soda}:  sup = 0.012
# {fruit/vegetable juice, salty snack}:  sup = 0.006
# {onions, rolls/buns}:  sup = 0.007
# {yogurt, chicken}:  sup = 0.008
# {long life bakery product, whipped/sour cream}:  sup = 0.006
# {shopping bags, curd}:  sup = 0.005
# {margarine, curd}:  sup = 0.006
# {newspapers, whole milk}:  sup = 0.027
# {yogurt, UHT-milk}:  sup = 0.007
# {specialty bar, rolls/buns}:  sup = 0.006
# {tropical fruit, salty snack}:  sup = 0.006
# {root vegetables, sliced cheese}:  sup = 0.006
# {bottled beer, soda}:  sup = 0.017
# {whole milk, sliced cheese}:  sup = 0.011
# {fruit/vegetable juice, tropical fruit}:  sup = 0.014
# {shopping bags, margarine}:  sup = 0.006
# {white bread, ham}:  sup = 0.005
# {margarine, tropical fruit}:  sup = 0.009
# {dessert, shopping bags}:  sup = 0.006
# {other vegetables, chocolate}:  sup = 0.013
# {pip fruit, frankfurter}:  sup = 0.007
# {fruit/vegetable juice, other vegetables}:  sup = 0.021
# {frankfurter, pastry}:  sup = 0.008
# {tropical fruit, rolls/buns}:  sup = 0.025
# {hygiene articles, other vegetables}:  sup = 0.01
# {other vegetables, UHT-milk}:  sup = 0.008
# {shopping bags, canned beer}:  sup = 0.011
# {whipped/sour cream, tropical fruit}:  sup = 0.014
# {bottled water, citrus fruit}:  sup = 0.014
# {tropical fruit, chicken}:  sup = 0.006
# {bottled water, canned beer}:  sup = 0.008
# {whole milk, beef}:  sup = 0.021
# {yogurt, sliced cheese}:  sup = 0.008
# {shopping bags, root vegetables}:  sup = 0.013
# {root vegetables, chocolate}:  sup = 0.006
# {root vegetables, sausage}:  sup = 0.015
# {whole milk, salty snack}:  sup = 0.011
# {cream cheese , domestic eggs}:  sup = 0.005
# {root vegetables, oil}:  sup = 0.007
# {pip fruit, brown bread}:  sup = 0.008
# {sausage, bottled beer}:  sup = 0.008
# {bottled beer, napkins}:  sup = 0.005
# {sausage, soda}:  sup = 0.024
# {fruit/vegetable juice, rolls/buns}:  sup = 0.015
# {shopping bags, salty snack}:  sup = 0.006
# {chewing gum, soda}:  sup = 0.005
# {tropical fruit, pork}:  sup = 0.009
# {root vegetables, hard cheese}:  sup = 0.006
# {domestic eggs, bottled water}:  sup = 0.009
# {napkins, rolls/buns}:  sup = 0.012
# {dessert, pastry}:  sup = 0.005
# {pip fruit, rolls/buns}:  sup = 0.014
# {yogurt, long life bakery product}:  sup = 0.009
# {white bread, whipped/sour cream}:  sup = 0.005
# {whole milk, other vegetables}:  sup = 0.075
# {shopping bags, brown bread}:  sup = 0.009
# {frozen vegetables, citrus fruit}:  sup = 0.007
# {yogurt, cream cheese}:  sup = 0.012
# {waffles, other vegetables}:  sup = 0.01
# {whole milk, pot plants}:  sup = 0.007
# {yogurt, frozen vegetables}:  sup = 0.012
# {frozen vegetables, soda}:  sup = 0.009
# {cream cheese , other vegetables}:  sup = 0.014
# {root vegetables, bottled beer}:  sup = 0.01
# {yogurt, meat}:  sup = 0.005
# {sausage, fruit/vegetable juice}:  sup = 0.01
# {other vegetables, onions}:  sup = 0.014
# {frankfurter, whipped/sour cream}:  sup = 0.006
# {fruit/vegetable juice, frozen vegetables}:  sup = 0.008
# {rolls/buns, pork}:  sup = 0.011
# {margarine, pork}:  sup = 0.006
# {hamburger meat, rolls/buns}:  sup = 0.009
# {newspapers, other vegetables}:  sup = 0.019
# {frankfurter, bottled beer}:  sup = 0.005
# {root vegetables, yogurt}:  sup = 0.026
# {tropical fruit, coffee}:  sup = 0.007
# {cream cheese , curd}:  sup = 0.005
# {citrus fruit, chocolate}:  sup = 0.006
# {newspapers, soda}:  sup = 0.015
# {yogurt, other vegetables}:  sup = 0.043
# {long life bakery product, soda}:  sup = 0.008
# {sausage, hard cheese}:  sup = 0.005
# {yogurt, ham}:  sup = 0.007
# {cream cheese , rolls/buns}:  sup = 0.01
# {soft cheese, other vegetables}:  sup = 0.007
# {other vegetables, sugar}:  sup = 0.011
# {root vegetables, berries}:  sup = 0.007
# {cream cheese , tropical fruit}:  sup = 0.007
# {pip fruit, citrus fruit}:  sup = 0.014
# {berries, other vegetables}:  sup = 0.01
# {onions, tropical fruit}:  sup = 0.006
# {whole milk, frozen meals}:  sup = 0.01
# {hamburger meat, soda}:  sup = 0.006
# {pip fruit, pork}:  sup = 0.006
# {yogurt, bottled water}:  sup = 0.023
# {pastry, beef}:  sup = 0.006
# {fruit/vegetable juice, butter}:  sup = 0.008
# {ham, tropical fruit}:  sup = 0.005
# {root vegetables, whole milk}:  sup = 0.049
# {yogurt, whole milk}:  sup = 0.056
# {frozen vegetables, rolls/buns}:  sup = 0.01
# {processed cheese, other vegetables}:  sup = 0.005
# {root vegetables, herbs}:  sup = 0.007
# {domestic eggs, whipped/sour cream}:  sup = 0.01
# {bottled water, chicken}:  sup = 0.005
# {berries, rolls/buns}:  sup = 0.007
# {newspapers, butter}:  sup = 0.006
# {other vegetables, frozen vegetables}:  sup = 0.018
# {fruit/vegetable juice, pastry}:  sup = 0.009
# {newspapers, domestic eggs}:  sup = 0.007
# {shopping bags, soda}:  sup = 0.025
# {bottled water, curd}:  sup = 0.006
# {whole milk, chicken}:  sup = 0.018
# {shopping bags, waffles}:  sup = 0.005
# {berries, citrus fruit}:  sup = 0.005
# {root vegetables, frankfurter}:  sup = 0.01
# {root vegetables, chicken}:  sup = 0.011
# {shopping bags, chocolate}:  sup = 0.008
# {whole milk, oil}:  sup = 0.011
# {shopping bags, newspapers}:  sup = 0.007
# {domestic eggs, butter}:  sup = 0.01
# {bottled beer, rolls/buns}:  sup = 0.014
# {sausage, rolls/buns}:  sup = 0.031
# {misc. beverages, soda}:  sup = 0.007
# {soda, pork}:  sup = 0.012
# {butter, soda}:  sup = 0.009
# {other vegetables, frozen meals}:  sup = 0.008
# {shopping bags, other vegetables}:  sup = 0.023
# {frozen vegetables, chicken}:  sup = 0.007
# {margarine, citrus fruit}:  sup = 0.008
# {frankfurter, pork}:  sup = 0.006
# {bottled water, coffee}:  sup = 0.007
# {other vegetables, pork}:  sup = 0.022
# {beverages, rolls/buns}:  sup = 0.005
# {bottled beer, whole milk}:  sup = 0.02
# {other vegetables, curd}:  sup = 0.017
# {cream cheese , fruit/vegetable juice}:  sup = 0.006
# {pip fruit, tropical fruit}:  sup = 0.02
# {other vegetables, chicken}:  sup = 0.018
# {margarine, sugar}:  sup = 0.005
# {other vegetables, sliced cheese}:  sup = 0.009
# {yogurt, oil}:  sup = 0.005
# {fruit/vegetable juice, bottled water}:  sup = 0.014
# {root vegetables, fruit/vegetable juice}:  sup = 0.012
# {brown bread, citrus fruit}:  sup = 0.008
# {yogurt, pastry}:  sup = 0.018
# {brown bread, rolls/buns}:  sup = 0.013
# {onions, citrus fruit}:  sup = 0.006
# {yogurt, hard cheese}:  sup = 0.006
# {butter, tropical fruit}:  sup = 0.01
# {bottled beer, citrus fruit}:  sup = 0.006
# {other vegetables, citrus fruit}:  sup = 0.029
# {rolls/buns, coffee}:  sup = 0.011
# {yogurt, frozen meals}:  sup = 0.006
# {onions, soda}:  sup = 0.005
# {tropical fruit, soda}:  sup = 0.021
# {grapes, other vegetables}:  sup = 0.009
# {candy, whole milk}:  sup = 0.008
# {bottled beer, pork}:  sup = 0.005
# {citrus fruit, rolls/buns}:  sup = 0.017
# {bottled water, chocolate}:  sup = 0.006
# {dessert, fruit/vegetable juice}:  sup = 0.006
# {domestic eggs, curd}:  sup = 0.007
# {chocolate, pastry}:  sup = 0.008
# {long life bakery product, tropical fruit}:  sup = 0.006
# {napkins, citrus fruit}:  sup = 0.008
# {root vegetables, long life bakery product}:  sup = 0.005
# {pip fruit, pastry}:  sup = 0.011
# {pickled vegetables, other vegetables}:  sup = 0.006
# {waffles, chocolate}:  sup = 0.006
# {whole milk, napkins}:  sup = 0.02
# {pip fruit, butter}:  sup = 0.007
# {domestic eggs, pastry}:  sup = 0.009
# {sugar, rolls/buns}:  sup = 0.007
# {napkins, soda}:  sup = 0.012
# {whole milk, pork}:  sup = 0.022
# {sausage, hamburger meat}:  sup = 0.005
# {newspapers, chocolate}:  sup = 0.005
# {dessert, root vegetables}:  sup = 0.006
# {shopping bags, cream cheese}:  sup = 0.006
# {frankfurter, frozen vegetables}:  sup = 0.005
# {pip fruit, whipped/sour cream}:  sup = 0.009
# {yogurt, sugar}:  sup = 0.007
# {other vegetables, misc. beverages}:  sup = 0.006
# {root vegetables, whipped/sour cream}:  sup = 0.017
# {shopping bags, tropical fruit}:  sup = 0.014
# {sausage, pork}:  sup = 0.007
# {cream cheese , whole milk}:  sup = 0.016
# {other vegetables, bottled water}:  sup = 0.025
# {whole milk, onions}:  sup = 0.012
# {citrus fruit, beef}:  sup = 0.008
# {root vegetables, butter}:  sup = 0.013
# {yogurt, berries}:  sup = 0.011
# {soda, specialty chocolate}:  sup = 0.006
# {sausage, other vegetables}:  sup = 0.027
# {citrus fruit, soda}:  sup = 0.013
# {frozen vegetables, butter}:  sup = 0.006
# {bottled water, onions}:  sup = 0.006
# {oil, rolls/buns}:  sup = 0.005
# {napkins, tropical fruit}:  sup = 0.01
# {rolls/buns, beef}:  sup = 0.014
# {frankfurter, whole milk}:  sup = 0.021
# {whole milk, whipped/sour cream}:  sup = 0.032
# {yogurt, napkins}:  sup = 0.012
# {newspapers, curd}:  sup = 0.006
# {specialty bar, soda}:  sup = 0.007
# {frankfurter, rolls/buns}:  sup = 0.019
# {frankfurter, bottled water}:  sup = 0.007
# {root vegetables, meat}:  sup = 0.005
# {shopping bags, citrus fruit}:  sup = 0.01
# {shopping bags, domestic eggs}:  sup = 0.009
# {sausage, margarine}:  sup = 0.007
# {yogurt, onions}:  sup = 0.007
# {root vegetables, newspapers}:  sup = 0.011
# {hygiene articles, tropical fruit}:  sup = 0.007
# {pip fruit, napkins}:  sup = 0.007
# {sausage, salty snack}:  sup = 0.005
# {other vegetables, beef}:  sup = 0.02
# {pip fruit, yogurt}:  sup = 0.018
# {pip fruit, butter milk}:  sup = 0.005
# {candy, rolls/buns}:  sup = 0.007
# {yogurt, waffles}:  sup = 0.008
# {whole milk, flour}:  sup = 0.008
# {margarine, rolls/buns}:  sup = 0.015
# {newspapers, napkins}:  sup = 0.006
# {fruit/vegetable juice, whole milk}:  sup = 0.027
# {soda, chicken}:  sup = 0.008
# {whole milk, brown bread}:  sup = 0.025
# {domestic eggs, margarine}:  sup = 0.008
# {bottled water, butter}:  sup = 0.009
# {curd, soda}:  sup = 0.008
# {specialty bar, whole milk}:  sup = 0.007
# {newspapers, pastry}:  sup = 0.008
# {other vegetables, butter milk}:  sup = 0.01
# {brown bread, pork}:  sup = 0.006
# {newspapers, bottled water}:  sup = 0.011
# {root vegetables, curd}:  sup = 0.011
# {brown bread, margarine}:  sup = 0.007
# {other vegetables, long life bakery product}:  sup = 0.011
# {bottled beer, margarine}:  sup = 0.006
# {bottled beer, butter}:  sup = 0.006
# {sausage, tropical fruit}:  sup = 0.014
# {napkins, pastry}:  sup = 0.007
# {beverages, whole milk}:  sup = 0.007
# {processed cheese, soda}:  sup = 0.005
# {root vegetables, pork}:  sup = 0.014
# {pip fruit, chocolate}:  sup = 0.006
# {root vegetables, coffee}:  sup = 0.007
# {frozen vegetables, bottled water}:  sup = 0.006
# {waffles, whole milk}:  sup = 0.013
# {frankfurter, margarine}:  sup = 0.006
# {bottled water, tropical fruit}:  sup = 0.019
# {root vegetables, domestic eggs}:  sup = 0.014
# {hygiene articles, rolls/buns}:  sup = 0.006
# {curd, pastry}:  sup = 0.008
# {butter, chocolate}:  sup = 0.006
# {other vegetables, coffee}:  sup = 0.013
# {newspapers, rolls/buns}:  sup = 0.02
# {bottled water, UHT-milk}:  sup = 0.007
# {fruit/vegetable juice, domestic eggs}:  sup = 0.008
# {other vegetables, detergent}:  sup = 0.006
# {white bread, domestic eggs}:  sup = 0.006
# {long life bakery product, pastry}:  sup = 0.006
# {yogurt, hygiene articles}:  sup = 0.007
# {UHT-milk, rolls/buns}:  sup = 0.006
# {sausage, coffee}:  sup = 0.007
# {root vegetables, hamburger meat}:  sup = 0.006
# {dessert, curd}:  sup = 0.005
# {other vegetables, tropical fruit}:  sup = 0.036
# {pip fruit, coffee}:  sup = 0.007
# {long life bakery product, chocolate}:  sup = 0.005
# {shopping bags, yogurt}:  sup = 0.015
# {whole milk, chocolate}:  sup = 0.017
# {white bread, fruit/vegetable juice}:  sup = 0.007
# {shopping bags, white bread}:  sup = 0.007
# {pip fruit, other vegetables}:  sup = 0.026
# {whole milk, ice cream}:  sup = 0.006
# {white bread, pastry}:  sup = 0.006
# {soda, ice cream}:  sup = 0.006
# {sausage, curd}:  sup = 0.008
# {sausage, domestic eggs}:  sup = 0.01
# {hygiene articles, whole milk}:  sup = 0.013
# {beverages, yogurt}:  sup = 0.005
# {whipped/sour cream, salty snack}:  sup = 0.005
# {bottled beer, brown bread}:  sup = 0.005
# {pip fruit, sausage}:  sup = 0.011
# {other vegetables, cat food}:  sup = 0.007
# {whole milk, detergent}:  sup = 0.009
# {specialty bar, other vegetables}:  sup = 0.006
# {bottled water, beef}:  sup = 0.006
# {soda, rolls/buns}:  sup = 0.038
# {yogurt, curd}:  sup = 0.017
# {root vegetables, sugar}:  sup = 0.006
# {root vegetables, frozen vegetables}:  sup = 0.012
# {hygiene articles, citrus fruit}:  sup = 0.005
# {soda, pastry}:  sup = 0.021
# {other vegetables, canned beer}:  sup = 0.009
# {whipped/sour cream, pork}:  sup = 0.008
# {shopping bags, napkins}:  sup = 0.007
# {sausage, long life bakery product}:  sup = 0.005
# {pip fruit, frozen vegetables}:  sup = 0.007
# {hygiene articles, soda}:  sup = 0.007
# {onions, whipped/sour cream}:  sup = 0.005
# {butter, rolls/buns}:  sup = 0.013
# {white bread, sausage}:  sup = 0.007
# {frozen meals, tropical fruit}:  sup = 0.005
# {butter, pork}:  sup = 0.005
# {yogurt, whipped/sour cream}:  sup = 0.021
# {whole milk, long life bakery product}:  sup = 0.014
# {other vegetables, napkins}:  sup = 0.014
# {domestic eggs, chicken}:  sup = 0.006
# {root vegetables, napkins}:  sup = 0.01
# {soft cheese, yogurt}:  sup = 0.006
# {domestic eggs, rolls/buns}:  sup = 0.016
# {ham, other vegetables}:  sup = 0.009
# {tropical fruit, chocolate}:  sup = 0.008
# {napkins, pork}:  sup = 0.005
# {margarine, pastry}:  sup = 0.007
# {root vegetables, bottled water}:  sup = 0.016
# {whole milk, frozen vegetables}:  sup = 0.02
# {pip fruit, bottled beer}:  sup = 0.006
# {frozen meals, soda}:  sup = 0.006
# {root vegetables, onions}:  sup = 0.009
# {fruit/vegetable juice, beef}:  sup = 0.005
# {pip fruit, bottled water}:  sup = 0.011
# {whipped/sour cream, butter}:  sup = 0.01
# {pip fruit, domestic eggs}:  sup = 0.009
# {other vegetables, specialty chocolate}:  sup = 0.006
# {candy, tropical fruit}:  sup = 0.005
# {frankfurter, fruit/vegetable juice}:  sup = 0.005
# {newspapers, whipped/sour cream}:  sup = 0.007
# {root vegetables, cream cheese}:  sup = 0.008
# {margarine, butter}:  sup = 0.007
# {citrus fruit, chicken}:  sup = 0.007
# {fruit/vegetable juice, margarine}:  sup = 0.006
# {whipped/sour cream, curd}:  sup = 0.01
# {domestic eggs, whole milk}:  sup = 0.03
# {pip fruit, fruit/vegetable juice}:  sup = 0.01
# {sausage, chocolate}:  sup = 0.007
# {bottled beer, other vegetables}:  sup = 0.016
# {waffles, whipped/sour cream}:  sup = 0.005
# {pip fruit, soda}:  sup = 0.013
# {candy, yogurt}:  sup = 0.005
# {sugar, soda}:  sup = 0.007
# {root vegetables, waffles}:  sup = 0.007
# {butter, curd}:  sup = 0.007
# {sausage, sliced cheese}:  sup = 0.007
# {white bread, other vegetables}:  sup = 0.014
# {other vegetables, canned fish}:  sup = 0.005
# {whole milk, soda}:  sup = 0.04
# {whole milk, pasta}:  sup = 0.006
# {whipped/sour cream, chicken}:  sup = 0.007
# {whole milk, citrus fruit}:  sup = 0.031
# {brown bread, pastry}:  sup = 0.01
# {candy, soda}:  sup = 0.009
# {waffles, pastry}:  sup = 0.007
# {chocolate, rolls/buns}:  sup = 0.012
# {shopping bags, rolls/buns}:  sup = 0.02
# {yogurt, pork}:  sup = 0.01
# {tropical fruit, beef}:  sup = 0.008
# {yogurt, coffee}:  sup = 0.01
# {whole milk, bottled water}:  sup = 0.034
# {sausage, frankfurter}:  sup = 0.01
# {yogurt, domestic eggs}:  sup = 0.014
# {shopping bags, fruit/vegetable juice}:  sup = 0.011
# {other vegetables, hamburger meat}:  sup = 0.014
# {bottled water, pastry}:  sup = 0.009
# {domestic eggs, other vegetables}:  sup = 0.022
# {root vegetables, tropical fruit}:  sup = 0.021
# {pip fruit, newspapers}:  sup = 0.007
# {whole milk, sugar}:  sup = 0.015
# {shopping bags, pastry}:  sup = 0.012
# {pork, chicken}:  sup = 0.006
# {berries, whipped/sour cream}:  sup = 0.009
# {domestic eggs, napkins}:  sup = 0.006
# {processed cheese, whole milk}:  sup = 0.007
# {yogurt, tropical fruit, curd}:  sup = 0.005
# {yogurt, whole milk, rolls/buns}:  sup = 0.016
# {tropical fruit, bottled water, soda}:  sup = 0.005
# {domestic eggs, soda, whole milk}:  sup = 0.005
# {domestic eggs, other vegetables, rolls/buns}:  sup = 0.006
# {other vegetables, tropical fruit, curd}:  sup = 0.005
# {shopping bags, root vegetables, whole milk}:  sup = 0.005
# {bottled beer, whole milk, other vegetables}:  sup = 0.008
# {yogurt, whole milk, brown bread}:  sup = 0.007
# {pip fruit, whole milk, rolls/buns}:  sup = 0.006
# {root vegetables, whole milk, brown bread}:  sup = 0.006
# {whole milk, whipped/sour cream, rolls/buns}:  sup = 0.008
# {pip fruit, citrus fruit, tropical fruit}:  sup = 0.006
# {domestic eggs, other vegetables, soda}:  sup = 0.005
# {root vegetables, other vegetables, curd}:  sup = 0.005
# {pip fruit, domestic eggs, whole milk}:  sup = 0.005
# {other vegetables, tropical fruit, soda}:  sup = 0.007
# {fruit/vegetable juice, whole milk, bottled water}:  sup = 0.006
# {root vegetables, other vegetables, onions}:  sup = 0.006
# {other vegetables, whipped/sour cream, whole milk}:  sup = 0.015
# {root vegetables, citrus fruit, tropical fruit}:  sup = 0.006
# {pip fruit, whole milk, citrus fruit}:  sup = 0.005
# {whole milk, butter, rolls/buns}:  sup = 0.007
# {other vegetables, citrus fruit, tropical fruit}:  sup = 0.009
# {root vegetables, other vegetables, pip fruit}:  sup = 0.008
# {root vegetables, other vegetables, citrus fruit}:  sup = 0.01
# {whole milk, brown bread, soda}:  sup = 0.005
# {domestic eggs, whole milk, other vegetables}:  sup = 0.012
# {pip fruit, whole milk, pastry}:  sup = 0.005
# {whole milk, curd, rolls/buns}:  sup = 0.006
# {yogurt, whole milk, napkins}:  sup = 0.006
# {root vegetables, other vegetables, margarine}:  sup = 0.006
# {tropical fruit, bottled water, rolls/buns}:  sup = 0.005
# {other vegetables, rolls/buns, whole milk}:  sup = 0.018
# {root vegetables, other vegetables, pastry}:  sup = 0.006
# {other vegetables, brown bread, whole milk}:  sup = 0.009
# {yogurt, whole milk, other vegetables}:  sup = 0.022
# {sausage, other vegetables, bottled water}:  sup = 0.005
# {newspapers, whole milk, rolls/buns}:  sup = 0.008
# {other vegetables, margarine, whole milk}:  sup = 0.009
# {whole milk, other vegetables, coffee}:  sup = 0.006
# {hygiene articles, other vegetables, whole milk}:  sup = 0.005
# {domestic eggs, whole milk, yogurt}:  sup = 0.008
# {whipped/sour cream, whole milk, citrus fruit}:  sup = 0.006
# {yogurt, whole milk, butter}:  sup = 0.009
# {domestic eggs, margarine, whole milk}:  sup = 0.005
# {pip fruit, other vegetables, tropical fruit}:  sup = 0.009
# {frankfurter, whole milk, tropical fruit}:  sup = 0.005
# {whole milk, margarine, rolls/buns}:  sup = 0.008
# {fruit/vegetable juice, whole milk, tropical fruit}:  sup = 0.006
# {yogurt, other vegetables, pastry}:  sup = 0.007
# {yogurt, other vegetables, whipped/sour cream}:  sup = 0.01
# {domestic eggs, whipped/sour cream, other vegetables}:  sup = 0.005
# {newspapers, other vegetables, rolls/buns}:  sup = 0.005
# {pip fruit, whole milk, yogurt}:  sup = 0.01
# {whole milk, other vegetables, curd}:  sup = 0.01
# {root vegetables, whole milk, curd}:  sup = 0.006
# {yogurt, whole milk, newspapers}:  sup = 0.007
# {other vegetables, frozen vegetables, whole milk}:  sup = 0.01
# {yogurt, whipped/sour cream, tropical fruit}:  sup = 0.006
# {whole milk, whipped/sour cream, curd}:  sup = 0.006
# {yogurt, tropical fruit, rolls/buns}:  sup = 0.009
# {whole milk, butter, tropical fruit}:  sup = 0.006
# {yogurt, newspapers, rolls/buns}:  sup = 0.005
# {whole milk, frozen vegetables, rolls/buns}:  sup = 0.005
# {whole milk, brown bread, rolls/buns}:  sup = 0.005
# {pip fruit, root vegetables, tropical fruit}:  sup = 0.005
# {yogurt, whole milk, frozen vegetables}:  sup = 0.006
# {pip fruit, yogurt, tropical fruit}:  sup = 0.006
# {soda, tropical fruit, rolls/buns}:  sup = 0.005
# {yogurt, other vegetables, newspapers}:  sup = 0.006
# {yogurt, whole milk, coffee}:  sup = 0.005
# {newspapers, whole milk, tropical fruit}:  sup = 0.005
# {root vegetables, fruit/vegetable juice, whole milk}:  sup = 0.007
# {yogurt, other vegetables, curd}:  sup = 0.006
# {other vegetables, butter, rolls/buns}:  sup = 0.006
# {domestic eggs, rolls/buns, whole milk}:  sup = 0.007
# {other vegetables, bottled water, tropical fruit}:  sup = 0.006
# {pip fruit, other vegetables, rolls/buns}:  sup = 0.005
# {whole milk, butter, other vegetables}:  sup = 0.011
# {other vegetables, soda, rolls/buns}:  sup = 0.01
# {whole milk, tropical fruit, soda}:  sup = 0.008
# {pip fruit, whole milk, tropical fruit}:  sup = 0.008
# {root vegetables, other vegetables, chicken}:  sup = 0.006
# {sausage, whole milk, yogurt}:  sup = 0.009
# {root vegetables, domestic eggs, whole milk}:  sup = 0.009
# {yogurt, other vegetables, sausage}:  sup = 0.008
# {yogurt, fruit/vegetable juice, whole milk}:  sup = 0.009
# {other vegetables, tropical fruit, rolls/buns}:  sup = 0.008
# {oil, other vegetables, whole milk}:  sup = 0.005
# {pip fruit, other vegetables, whipped/sour cream}:  sup = 0.006
# {soda, whole milk, rolls/buns}:  sup = 0.009
# {root vegetables, whole milk, bottled water}:  sup = 0.007
# {yogurt, fruit/vegetable juice, other vegetables}:  sup = 0.008
# {root vegetables, other vegetables, whipped/sour cream}:  sup = 0.009
# {whole milk, citrus fruit, rolls/buns}:  sup = 0.007
# {root vegetables, other vegetables, yogurt}:  sup = 0.013
# {newspapers, other vegetables, root vegetables}:  sup = 0.006
# {yogurt, other vegetables, butter}:  sup = 0.006
# {domestic eggs, whipped/sour cream, whole milk}:  sup = 0.006
# {other vegetables, citrus fruit, whole milk}:  sup = 0.013
# {newspapers, whole milk, other vegetables}:  sup = 0.008
# {whole milk, bottled water, tropical fruit}:  sup = 0.008
# {whipped/sour cream, whole milk, butter}:  sup = 0.007
# {other vegetables, citrus fruit, rolls/buns}:  sup = 0.006
# {other vegetables, long life bakery product, whole milk}:  sup = 0.006
# {yogurt, citrus fruit, rolls/buns}:  sup = 0.006
# {yogurt, whole milk, pastry}:  sup = 0.009
# {whipped/sour cream, other vegetables, butter}:  sup = 0.006
# {sausage, whole milk, whipped/sour cream}:  sup = 0.005
# {root vegetables, whole milk, soda}:  sup = 0.008
# {other vegetables, bottled water, rolls/buns}:  sup = 0.007
# {yogurt, other vegetables, rolls/buns}:  sup = 0.011
# {whole milk, sugar, other vegetables}:  sup = 0.006
# {shopping bags, sausage, soda}:  sup = 0.006
# {other vegetables, rolls/buns, pastry}:  sup = 0.006
# {whole milk, bottled water, citrus fruit}:  sup = 0.006
# {shopping bags, root vegetables, other vegetables}:  sup = 0.007
# {root vegetables, tropical fruit, yogurt}:  sup = 0.008
# {yogurt, domestic eggs, other vegetables}:  sup = 0.006
# {sausage, whole milk, pastry}:  sup = 0.006
# {frankfurter, whole milk, rolls/buns}:  sup = 0.006
# {sausage, other vegetables, rolls/buns}:  sup = 0.009
# {other vegetables, bottled water, whole milk}:  sup = 0.011
# {yogurt, other vegetables, brown bread}:  sup = 0.005
# {other vegetables, chocolate, whole milk}:  sup = 0.005
# {root vegetables, other vegetables, bottled water}:  sup = 0.007
# {yogurt, tropical fruit, soda}:  sup = 0.007
# {yogurt, other vegetables, margarine}:  sup = 0.006
# {sausage, other vegetables, tropical fruit}:  sup = 0.006
# {yogurt, other vegetables, citrus fruit}:  sup = 0.008
# {whole milk, bottled water, rolls/buns}:  sup = 0.009
# {whole milk, citrus fruit, tropical fruit}:  sup = 0.009
# {root vegetables, whole milk, citrus fruit}:  sup = 0.009
# {root vegetables, whole milk, butter}:  sup = 0.008
# {root vegetables, sausage, whole milk}:  sup = 0.008
# {root vegetables, whole milk, pork}:  sup = 0.007
# {other vegetables, soda, whole milk}:  sup = 0.014
# {yogurt, other vegetables, beef}:  sup = 0.005
# {shopping bags, soda, rolls/buns}:  sup = 0.006
# {yogurt, bottled beer, whole milk}:  sup = 0.005
# {fruit/vegetable juice, whole milk, soda}:  sup = 0.006
# {other vegetables, whipped/sour cream, rolls/buns}:  sup = 0.007
# {yogurt, frankfurter, whole milk}:  sup = 0.006
# {root vegetables, whole milk, tropical fruit}:  sup = 0.012
# {root vegetables, fruit/vegetable juice, other vegetables}:  sup = 0.007
# {yogurt, fruit/vegetable juice, soda}:  sup = 0.005
# {yogurt, other vegetables, frozen vegetables}:  sup = 0.005
# {sausage, whole milk, tropical fruit}:  sup = 0.007
# {pip fruit, whole milk, other vegetables}:  sup = 0.014
# {whole milk, bottled water, butter}:  sup = 0.005
# {other vegetables, margarine, rolls/buns}:  sup = 0.005
# {yogurt, rolls/buns, pastry}:  sup = 0.006
# {sausage, soda, yogurt}:  sup = 0.006
# {yogurt, bottled water, rolls/buns}:  sup = 0.007
# {whole milk, butter, citrus fruit}:  sup = 0.005
# {root vegetables, whole milk, beef}:  sup = 0.008
# {whole milk, brown bread, tropical fruit}:  sup = 0.006
# {white bread, whole milk, other vegetables}:  sup = 0.006
# {yogurt, cream cheese , other vegetables}:  sup = 0.005
# {yogurt, other vegetables, soda}:  sup = 0.008
# {root vegetables, other vegetables, soda}:  sup = 0.008
# {shopping bags, sausage, rolls/buns}:  sup = 0.006
# {whole milk, other vegetables, beef}:  sup = 0.009
# {root vegetables, whole milk, pastry}:  sup = 0.006
# {yogurt, whole milk, citrus fruit}:  sup = 0.01
# {root vegetables, other vegetables, pork}:  sup = 0.007
# {shopping bags, yogurt, whole milk}:  sup = 0.005
# {yogurt, bottled water, tropical fruit}:  sup = 0.007
# {shopping bags, whole milk, soda}:  sup = 0.007
# {whole milk, tropical fruit, curd}:  sup = 0.007
# {shopping bags, other vegetables, rolls/buns}:  sup = 0.005
# {pip fruit, root vegetables, whole milk}:  sup = 0.009
# {yogurt, whole milk, beef}:  sup = 0.006
# {shopping bags, yogurt, other vegetables}:  sup = 0.005
# {root vegetables, whipped/sour cream, yogurt}:  sup = 0.006
# {other vegetables, tropical fruit, pastry}:  sup = 0.005
# {whole milk, soda, pastry}:  sup = 0.008
# {soda, bottled water, rolls/buns}:  sup = 0.007
# {fruit/vegetable juice, whole milk, rolls/buns}:  sup = 0.006
# {sausage, whole milk, soda}:  sup = 0.007
# {whole milk, tropical fruit, rolls/buns}:  sup = 0.011
# {whole milk, hamburger meat, other vegetables}:  sup = 0.006
# {yogurt, whole milk, bottled water}:  sup = 0.01
# {whole milk, other vegetables, chicken}:  sup = 0.008
# {root vegetables, whole milk, yogurt}:  sup = 0.015
# {other vegetables, whole milk, pastry}:  sup = 0.011
# {yogurt, sausage, rolls/buns}:  sup = 0.006
# {sausage, whole milk, other vegetables}:  sup = 0.01
# {sausage, soda, rolls/buns}:  sup = 0.01
# {domestic eggs, whole milk, butter}:  sup = 0.006
# {other vegetables, onions, whole milk}:  sup = 0.007
# {yogurt, soda, rolls/buns}:  sup = 0.009
# {root vegetables, domestic eggs, other vegetables}:  sup = 0.007
# {root vegetables, whole milk, chicken}:  sup = 0.006
# {whole milk, other vegetables, pork}:  sup = 0.01
# {yogurt, root vegetables, rolls/buns}:  sup = 0.007
# {root vegetables, frankfurter, whole milk}:  sup = 0.005
# {yogurt, whole milk, tropical fruit}:  sup = 0.015
# {fruit/vegetable juice, other vegetables, whole milk}:  sup = 0.01
# {shopping bags, whole milk, other vegetables}:  sup = 0.008
# {root vegetables, other vegetables, beef}:  sup = 0.008
# {chocolate, whole milk, soda}:  sup = 0.005
# {root vegetables, whole milk, whipped/sour cream}:  sup = 0.009
# {root vegetables, other vegetables, whole milk}:  sup = 0.023
# {yogurt, whole milk, whipped/sour cream}:  sup = 0.011
# {shopping bags, other vegetables, soda}:  sup = 0.005
# {root vegetables, other vegetables, frozen vegetables}:  sup = 0.006
# {whole milk, whipped/sour cream, soda}:  sup = 0.005
# {pip fruit, whole milk, whipped/sour cream}:  sup = 0.006
# {bottled beer, whole milk, bottled water}:  sup = 0.006
# {whole milk, napkins, rolls/buns}:  sup = 0.005
# {sausage, whole milk, rolls/buns}:  sup = 0.009
# {sausage, other vegetables, soda}:  sup = 0.007
# {bottled beer, whole milk, rolls/buns}:  sup = 0.005
# {soda, rolls/buns, pastry}:  sup = 0.005
# {yogurt, whole milk, curd}:  sup = 0.01
# {other vegetables, butter, tropical fruit}:  sup = 0.005
# {newspapers, whole milk, root vegetables}:  sup = 0.006
# {pip fruit, root vegetables, yogurt}:  sup = 0.005
# {root vegetables, other vegetables, butter}:  sup = 0.007
# {other vegetables, bottled water, soda}:  sup = 0.006
# {frankfurter, other vegetables, whole milk}:  sup = 0.008
# {root vegetables, whole milk, rolls/buns}:  sup = 0.013
# {other vegetables, bottled water, citrus fruit}:  sup = 0.005
# {yogurt, whole milk, soda}:  sup = 0.01
# {pip fruit, other vegetables, citrus fruit}:  sup = 0.006
# {root vegetables, tropical fruit, rolls/buns}:  sup = 0.006
# {yogurt, whole milk, margarine}:  sup = 0.007
# {whole milk, whipped/sour cream, tropical fruit}:  sup = 0.008
# {whole milk, tropical fruit, other vegetables}:  sup = 0.017
# {root vegetables, other vegetables, rolls/buns}:  sup = 0.012
# {yogurt, other vegetables, bottled water}:  sup = 0.008
# {frankfurter, other vegetables, rolls/buns}:  sup = 0.006
# {whole milk, rolls/buns, chicken}:  sup = 0.005
# {whole milk, napkins, other vegetables}:  sup = 0.007
# {other vegetables, rolls/buns, beef}:  sup = 0.006
# {shopping bags, sausage, other vegetables}:  sup = 0.005
# {whole milk, rolls/buns, beef}:  sup = 0.007
# {yogurt, citrus fruit, tropical fruit}:  sup = 0.006
# {root vegetables, sausage, yogurt}:  sup = 0.005
# {yogurt, other vegetables, pip fruit}:  sup = 0.008
# {root vegetables, other vegetables, tropical fruit}:  sup = 0.012
# {yogurt, bottled water, soda}:  sup = 0.007
# {yogurt, other vegetables, tropical fruit}:  sup = 0.012
# {fruit/vegetable juice, bottled water, soda}:  sup = 0.005
# {domestic eggs, tropical fruit, whole milk}:  sup = 0.007
# {pip fruit, whole milk, sausage}:  sup = 0.006
# {whipped/sour cream, other vegetables, citrus fruit}:  sup = 0.006
# {root vegetables, other vegetables, sausage}:  sup = 0.007
# {whole milk, rolls/buns, pastry}:  sup = 0.009
# {shopping bags, whole milk, rolls/buns}:  sup = 0.005
# {other vegetables, soda, pastry}:  sup = 0.005
# {other vegetables, rolls/buns, pork}:  sup = 0.006
# {bottled beer, bottled water, soda}:  sup = 0.005
# {fruit/vegetable juice, other vegetables, tropical fruit}:  sup = 0.007
# {other vegetables, whipped/sour cream, tropical fruit}:  sup = 0.008
# {whole milk, tropical fruit, pastry}:  sup = 0.007
# {cream cheese , other vegetables, whole milk}:  sup = 0.007
# {root vegetables, whole milk, frozen vegetables}:  sup = 0.006
# {whole milk, rolls/buns, pork}:  sup = 0.006
# {yogurt, cream cheese , whole milk}:  sup = 0.007
# {whole milk, bottled water, soda}:  sup = 0.008
# {domestic eggs, citrus fruit, whole milk}:  sup = 0.006
# {yogurt, other vegetables, fruit/vegetable juice, whole milk}:  sup = 0.005
# {root vegetables, other vegetables, whole milk, citrus fruit}:  sup = 0.006
# {yogurt, other vegetables, whole milk, whipped/sour cream}:  sup = 0.006
# {root vegetables, other vegetables, whole milk, whipped/sour cream}:  sup = 0.005
# {root vegetables, other vegetables, tropical fruit, whole milk}:  sup = 0.007
# {yogurt, other vegetables, tropical fruit, whole milk}:  sup = 0.008
# {yogurt, other vegetables, pip fruit, whole milk}:  sup = 0.005
# {yogurt, other vegetables, whole milk, rolls/buns}:  sup = 0.006
# {root vegetables, other vegetables, whole milk, rolls/buns}:  sup = 0.006
# {root vegetables, yogurt, other vegetables, whole milk}:  sup = 0.008
# {root vegetables, other vegetables, pip fruit, whole milk}:  sup = 0.005
# {root vegetables, yogurt, tropical fruit, whole milk}:  sup = 0.006

# %%
# Generate the association rules from a list of frequent itemsets.
H = generate_rules(F, support_data, min_confidence=0.6, verbose=True)
# Out:
# {pip fruit, domestic eggs} ---> {whole milk}:  conf = 0.624, sup = 0.005
# {root vegetables, onions} ---> {other vegetables}:  conf = 0.602, sup = 0.006
# {yogurt, butter} ---> {whole milk}:  conf = 0.639, sup = 0.009
# {domestic eggs, margarine} ---> {whole milk}:  conf = 0.622, sup = 0.005
# {butter, tropical fruit} ---> {whole milk}:  conf = 0.622, sup = 0.006
# {pip fruit, whipped/sour cream} ---> {other vegetables}:  conf = 0.604, sup = 0.006
# {whipped/sour cream, butter} ---> {whole milk}:  conf = 0.66, sup = 0.007
# {root vegetables, butter} ---> {whole milk}:  conf = 0.638, sup = 0.008
# {bottled water, butter} ---> {whole milk}:  conf = 0.602, sup = 0.005
# {curd, tropical fruit} ---> {whole milk}:  conf = 0.634, sup = 0.007
# {domestic eggs, butter} ---> {whole milk}:  conf = 0.621, sup = 0.006
# {pip fruit, whipped/sour cream} ---> {whole milk}:  conf = 0.648, sup = 0.006
# {domestic eggs, tropical fruit} ---> {whole milk}:  conf = 0.607, sup = 0.007
# {yogurt, fruit/vegetable juice, other vegetables} ---> {whole milk}:  conf = 0.617, sup = 0.005
# {root vegetables, whole milk, citrus fruit} ---> {other vegetables}:  conf = 0.633, sup = 0.006
# {root vegetables, other vegetables, whipped/sour cream} ---> {whole milk}:  conf = 0.607, sup = 0.005
# {yogurt, other vegetables, tropical fruit} ---> {whole milk}:  conf = 0.62, sup = 0.008
# {yogurt, other vegetables, pip fruit} ---> {whole milk}:  conf = 0.625, sup = 0.005
# {root vegetables, other vegetables, yogurt} ---> {whole milk}:  conf = 0.606, sup = 0.008
# {root vegetables, whole milk, pip fruit} ---> {other vegetables}:  conf = 0.614, sup = 0.005
# {root vegetables, other vegetables, pip fruit} ---> {whole milk}:  conf = 0.675, sup = 0.005
# {root vegetables, tropical fruit, yogurt} ---> {whole milk}:  conf = 0.7, sup = 0.006

# %% [markdown]
# ## Part 2: FP-Growth algorithm

# %%
# Generate all the frequent itemsets using the FP-growth algorithm.
F, support_data = fpgrowth(dataset, min_support=0.005, verbose=True)
# Out:
# {dishes}:  sup = 0.018
# {other vegetables, dishes}:  sup = 0.006
# {whole milk, dishes}:  sup = 0.005
# {yogurt}:  sup = 0.14
# {whole milk, yogurt}:  sup = 0.056
# {other vegetables, yogurt}:  sup = 0.043
# {whole milk, other vegetables, yogurt}:  sup = 0.022
# {rolls/buns, yogurt}:  sup = 0.034
# {whole milk, rolls/buns, yogurt}:  sup = 0.016
# {other vegetables, rolls/buns, yogurt}:  sup = 0.011
# {whole milk, other vegetables, rolls/buns, yogurt}:  sup = 0.006
# {soda, yogurt}:  sup = 0.027
# {whole milk, soda, yogurt}:  sup = 0.01
# {other vegetables, soda, yogurt}:  sup = 0.008
# {rolls/buns, soda, yogurt}:  sup = 0.009
# {detergent}:  sup = 0.019
# {other vegetables, detergent}:  sup = 0.006
# {whole milk, detergent}:  sup = 0.009
# {canned beer}:  sup = 0.078
# {yogurt, canned beer}:  sup = 0.005
# {soda, canned beer}:  sup = 0.014
# {sausage, canned beer}:  sup = 0.006
# {shopping bags, canned beer}:  sup = 0.011
# {other vegetables, canned beer}:  sup = 0.009
# {whole milk, canned beer}:  sup = 0.009
# {bottled water, canned beer}:  sup = 0.008
# {rolls/buns, canned beer}:  sup = 0.011
# {mayonnaise}:  sup = 0.009
# {liquor (appetizer)}:  sup = 0.008
# {frozen meals}:  sup = 0.028
# {yogurt, frozen meals}:  sup = 0.006
# {soda, frozen meals}:  sup = 0.006
# {tropical fruit, frozen meals}:  sup = 0.005
# {other vegetables, frozen meals}:  sup = 0.008
# {whole milk, frozen meals}:  sup = 0.01
# {flower (seeds)}:  sup = 0.01
# {zwieback}:  sup = 0.007
# {newspapers}:  sup = 0.08
# {yogurt, newspapers}:  sup = 0.015
# {whole milk, yogurt, newspapers}:  sup = 0.007
# {other vegetables, yogurt, newspapers}:  sup = 0.006
# {rolls/buns, yogurt, newspapers}:  sup = 0.005
# {soda, newspapers}:  sup = 0.015
# {pastry, newspapers}:  sup = 0.008
# {shopping bags, newspapers}:  sup = 0.007
# {sausage, newspapers}:  sup = 0.008
# {other vegetables, newspapers}:  sup = 0.019
# {whole milk, other vegetables, newspapers}:  sup = 0.008
# {tropical fruit, newspapers}:  sup = 0.012
# {whole milk, tropical fruit, newspapers}:  sup = 0.005
# {root vegetables, newspapers}:  sup = 0.011
# {other vegetables, root vegetables, newspapers}:  sup = 0.006
# {whole milk, root vegetables, newspapers}:  sup = 0.006
# {whole milk, newspapers}:  sup = 0.027
# {bottled water, newspapers}:  sup = 0.011
# {citrus fruit, newspapers}:  sup = 0.008
# {rolls/buns, newspapers}:  sup = 0.02
# {whole milk, rolls/buns, newspapers}:  sup = 0.008
# {other vegetables, rolls/buns, newspapers}:  sup = 0.005
# {frozen dessert}:  sup = 0.011
# {canned vegetables}:  sup = 0.011
# {chewing gum}:  sup = 0.021
# {soda, chewing gum}:  sup = 0.005
# {whole milk, chewing gum}:  sup = 0.005
# {fruit/vegetable juice}:  sup = 0.072
# {root vegetables, fruit/vegetable juice}:  sup = 0.012
# {other vegetables, root vegetables, fruit/vegetable juice}:  sup = 0.007
# {whole milk, root vegetables, fruit/vegetable juice}:  sup = 0.007
# {soda, fruit/vegetable juice}:  sup = 0.018
# {whole milk, soda, fruit/vegetable juice}:  sup = 0.006
# {sausage, fruit/vegetable juice}:  sup = 0.01
# {shopping bags, fruit/vegetable juice}:  sup = 0.011
# {pip fruit, fruit/vegetable juice}:  sup = 0.01
# {bottled beer, fruit/vegetable juice}:  sup = 0.007
# {pastry, fruit/vegetable juice}:  sup = 0.009
# {yogurt, fruit/vegetable juice}:  sup = 0.019
# {whole milk, yogurt, fruit/vegetable juice}:  sup = 0.009
# {soda, yogurt, fruit/vegetable juice}:  sup = 0.005
# {other vegetables, yogurt, fruit/vegetable juice}:  sup = 0.008
# {whole milk, other vegetables, yogurt, fruit/vegetable juice}:  sup = 0.005
# {newspapers, fruit/vegetable juice}:  sup = 0.008
# {other vegetables, fruit/vegetable juice}:  sup = 0.021
# {whole milk, other vegetables, fruit/vegetable juice}:  sup = 0.01
# {tropical fruit, fruit/vegetable juice}:  sup = 0.014
# {other vegetables, tropical fruit, fruit/vegetable juice}:  sup = 0.007
# {whole milk, tropical fruit, fruit/vegetable juice}:  sup = 0.006
# {whole milk, fruit/vegetable juice}:  sup = 0.027
# {bottled water, fruit/vegetable juice}:  sup = 0.014
# {soda, bottled water, fruit/vegetable juice}:  sup = 0.005
# {whole milk, bottled water, fruit/vegetable juice}:  sup = 0.006
# {citrus fruit, fruit/vegetable juice}:  sup = 0.01
# {rolls/buns, fruit/vegetable juice}:  sup = 0.015
# {whole milk, rolls/buns, fruit/vegetable juice}:  sup = 0.006
# {spices}:  sup = 0.005
# {margarine}:  sup = 0.059
# {yogurt, margarine}:  sup = 0.014
# {whole milk, yogurt, margarine}:  sup = 0.007
# {other vegetables, yogurt, margarine}:  sup = 0.006
# {soda, margarine}:  sup = 0.01
# {pastry, margarine}:  sup = 0.007
# {bottled beer, margarine}:  sup = 0.006
# {whipped/sour cream, margarine}:  sup = 0.007
# {newspapers, margarine}:  sup = 0.007
# {fruit/vegetable juice, margarine}:  sup = 0.006
# {citrus fruit, margarine}:  sup = 0.008
# {rolls/buns, margarine}:  sup = 0.015
# {whole milk, rolls/buns, margarine}:  sup = 0.008
# {other vegetables, rolls/buns, margarine}:  sup = 0.005
# {bottled water, margarine}:  sup = 0.01
# {root vegetables, margarine}:  sup = 0.011
# {other vegetables, root vegetables, margarine}:  sup = 0.006
# {frankfurter, margarine}:  sup = 0.006
# {shopping bags, margarine}:  sup = 0.006
# {pip fruit, margarine}:  sup = 0.009
# {domestic eggs, margarine}:  sup = 0.008
# {whole milk, domestic eggs, margarine}:  sup = 0.005
# {sausage, margarine}:  sup = 0.007
# {other vegetables, margarine}:  sup = 0.02
# {whole milk, other vegetables, margarine}:  sup = 0.009
# {brown bread, margarine}:  sup = 0.007
# {tropical fruit, margarine}:  sup = 0.009
# {whole milk, margarine}:  sup = 0.024
# {berries}:  sup = 0.033
# {yogurt, berries}:  sup = 0.011
# {whipped/sour cream, berries}:  sup = 0.009
# {citrus fruit, berries}:  sup = 0.005
# {rolls/buns, berries}:  sup = 0.007
# {root vegetables, berries}:  sup = 0.007
# {soda, berries}:  sup = 0.007
# {other vegetables, berries}:  sup = 0.01
# {tropical fruit, berries}:  sup = 0.007
# {whole milk, berries}:  sup = 0.012
# {rolls/buns}:  sup = 0.184
# {other vegetables, rolls/buns}:  sup = 0.043
# {whole milk, other vegetables, rolls/buns}:  sup = 0.018
# {whole milk, rolls/buns}:  sup = 0.057
# {butter milk}:  sup = 0.028
# {yogurt, butter milk}:  sup = 0.009
# {rolls/buns, butter milk}:  sup = 0.008
# {root vegetables, butter milk}:  sup = 0.005
# {tropical fruit, butter milk}:  sup = 0.005
# {pip fruit, butter milk}:  sup = 0.005
# {other vegetables, butter milk}:  sup = 0.01
# {whole milk, butter milk}:  sup = 0.012
# {soft cheese}:  sup = 0.017
# {yogurt, soft cheese}:  sup = 0.006
# {rolls/buns, soft cheese}:  sup = 0.005
# {other vegetables, soft cheese}:  sup = 0.007
# {whole milk, soft cheese}:  sup = 0.008
# {popcorn}:  sup = 0.007
# {napkins}:  sup = 0.052
# {yogurt, napkins}:  sup = 0.012
# {whole milk, yogurt, napkins}:  sup = 0.006
# {soda, napkins}:  sup = 0.012
# {bottled beer, napkins}:  sup = 0.005
# {whipped/sour cream, napkins}:  sup = 0.007
# {newspapers, napkins}:  sup = 0.006
# {fruit/vegetable juice, napkins}:  sup = 0.007
# {bottled water, napkins}:  sup = 0.009
# {citrus fruit, napkins}:  sup = 0.008
# {rolls/buns, napkins}:  sup = 0.012
# {whole milk, rolls/buns, napkins}:  sup = 0.005
# {pork, napkins}:  sup = 0.005
# {root vegetables, napkins}:  sup = 0.01
# {shopping bags, napkins}:  sup = 0.007
# {pip fruit, napkins}:  sup = 0.007
# {domestic eggs, napkins}:  sup = 0.006
# {sausage, napkins}:  sup = 0.007
# {other vegetables, napkins}:  sup = 0.014
# {whole milk, other vegetables, napkins}:  sup = 0.007
# {pastry, napkins}:  sup = 0.007
# {tropical fruit, napkins}:  sup = 0.01
# {whole milk, napkins}:  sup = 0.02
# {semi-finished bread}:  sup = 0.018
# {other vegetables, semi-finished bread}:  sup = 0.005
# {whole milk, semi-finished bread}:  sup = 0.007
# {chicken}:  sup = 0.043
# {yogurt, chicken}:  sup = 0.008
# {soda, chicken}:  sup = 0.008
# {whipped/sour cream, chicken}:  sup = 0.007
# {newspapers, chicken}:  sup = 0.005
# {bottled water, chicken}:  sup = 0.005
# {citrus fruit, chicken}:  sup = 0.007
# {rolls/buns, chicken}:  sup = 0.01
# {whole milk, rolls/buns, chicken}:  sup = 0.005
# {pork, chicken}:  sup = 0.006
# {root vegetables, chicken}:  sup = 0.011
# {other vegetables, root vegetables, chicken}:  sup = 0.006
# {whole milk, root vegetables, chicken}:  sup = 0.006
# {domestic eggs, chicken}:  sup = 0.006
# {frozen vegetables, chicken}:  sup = 0.007
# {butter, chicken}:  sup = 0.006
# {sausage, chicken}:  sup = 0.005
# {other vegetables, chicken}:  sup = 0.018
# {whole milk, other vegetables, chicken}:  sup = 0.008
# {tropical fruit, chicken}:  sup = 0.006
# {whole milk, chicken}:  sup = 0.018
# {cereals}:  sup = 0.006
# {coffee}:  sup = 0.058
# {yogurt, coffee}:  sup = 0.01
# {whole milk, yogurt, coffee}:  sup = 0.005
# {soda, coffee}:  sup = 0.01
# {pastry, coffee}:  sup = 0.007
# {whipped/sour cream, coffee}:  sup = 0.006
# {fruit/vegetable juice, coffee}:  sup = 0.006
# {citrus fruit, coffee}:  sup = 0.006
# {rolls/buns, coffee}:  sup = 0.011
# {bottled water, coffee}:  sup = 0.007
# {root vegetables, coffee}:  sup = 0.007
# {frankfurter, coffee}:  sup = 0.005
# {shopping bags, coffee}:  sup = 0.009
# {pip fruit, coffee}:  sup = 0.007
# {sausage, coffee}:  sup = 0.007
# {other vegetables, coffee}:  sup = 0.013
# {whole milk, other vegetables, coffee}:  sup = 0.006
# {tropical fruit, coffee}:  sup = 0.007
# {whole milk, coffee}:  sup = 0.019
# {hamburger meat}:  sup = 0.033
# {yogurt, hamburger meat}:  sup = 0.007
# {soda, hamburger meat}:  sup = 0.006
# {rolls/buns, hamburger meat}:  sup = 0.009
# {root vegetables, hamburger meat}:  sup = 0.006
# {sausage, hamburger meat}:  sup = 0.005
# {other vegetables, hamburger meat}:  sup = 0.014
# {whole milk, other vegetables, hamburger meat}:  sup = 0.006
# {whole milk, hamburger meat}:  sup = 0.015
# {brown bread}:  sup = 0.065
# {yogurt, brown bread}:  sup = 0.015
# {whole milk, yogurt, brown bread}:  sup = 0.007
# {other vegetables, yogurt, brown bread}:  sup = 0.005
# {soda, brown bread}:  sup = 0.013
# {whole milk, soda, brown bread}:  sup = 0.005
# {root vegetables, brown bread}:  sup = 0.01
# {whole milk, root vegetables, brown bread}:  sup = 0.006
# {shopping bags, brown bread}:  sup = 0.009
# {sausage, brown bread}:  sup = 0.011
# {bottled beer, brown bread}:  sup = 0.005
# {pastry, brown bread}:  sup = 0.01
# {newspapers, brown bread}:  sup = 0.008
# {other vegetables, brown bread}:  sup = 0.019
# {whole milk, other vegetables, brown bread}:  sup = 0.009
# {tropical fruit, brown bread}:  sup = 0.011
# {whole milk, tropical fruit, brown bread}:  sup = 0.006
# {pip fruit, brown bread}:  sup = 0.008
# {fruit/vegetable juice, brown bread}:  sup = 0.008
# {whole milk, brown bread}:  sup = 0.025
# {bottled water, brown bread}:  sup = 0.008
# {citrus fruit, brown bread}:  sup = 0.008
# {rolls/buns, brown bread}:  sup = 0.013
# {whole milk, rolls/buns, brown bread}:  sup = 0.005
# {beverages}:  sup = 0.026
# {yogurt, beverages}:  sup = 0.005
# {rolls/buns, beverages}:  sup = 0.005
# {other vegetables, beverages}:  sup = 0.005
# {whole milk, beverages}:  sup = 0.007
# {salty snack}:  sup = 0.038
# {fruit/vegetable juice, salty snack}:  sup = 0.006
# {yogurt, salty snack}:  sup = 0.006
# {tropical fruit, salty snack}:  sup = 0.006
# {soda, salty snack}:  sup = 0.009
# {whipped/sour cream, salty snack}:  sup = 0.005
# {shopping bags, salty snack}:  sup = 0.006
# {pastry, salty snack}:  sup = 0.005
# {sausage, salty snack}:  sup = 0.005
# {other vegetables, salty snack}:  sup = 0.011
# {whole milk, salty snack}:  sup = 0.011
# {packaged fruit/vegetables}:  sup = 0.013
# {ham}:  sup = 0.026
# {yogurt, ham}:  sup = 0.007
# {white bread, ham}:  sup = 0.005
# {rolls/buns, ham}:  sup = 0.007
# {tropical fruit, ham}:  sup = 0.005
# {other vegetables, ham}:  sup = 0.009
# {whole milk, ham}:  sup = 0.011
# {UHT-milk}:  sup = 0.033
# {yogurt, UHT-milk}:  sup = 0.007
# {soda, UHT-milk}:  sup = 0.008
# {rolls/buns, UHT-milk}:  sup = 0.006
# {bottled water, UHT-milk}:  sup = 0.007
# {other vegetables, UHT-milk}:  sup = 0.008
# {bottled beer}:  sup = 0.081
# {yogurt, bottled beer}:  sup = 0.009
# {whole milk, yogurt, bottled beer}:  sup = 0.005
# {soda, bottled beer}:  sup = 0.017
# {root vegetables, bottled beer}:  sup = 0.01
# {shopping bags, bottled beer}:  sup = 0.006
# {sausage, bottled beer}:  sup = 0.008
# {other vegetables, bottled beer}:  sup = 0.016
# {whole milk, other vegetables, bottled beer}:  sup = 0.008
# {tropical fruit, bottled beer}:  sup = 0.008
# {whole milk, bottled beer}:  sup = 0.02
# {bottled water, bottled beer}:  sup = 0.016
# {soda, bottled water, bottled beer}:  sup = 0.005
# {whole milk, bottled water, bottled beer}:  sup = 0.006
# {citrus fruit, bottled beer}:  sup = 0.006
# {rolls/buns, bottled beer}:  sup = 0.014
# {whole milk, rolls/buns, bottled beer}:  sup = 0.005
# {sparkling wine}:  sup = 0.006
# {white wine}:  sup = 0.019
# {cling film/bags}:  sup = 0.011
# {cat food}:  sup = 0.023
# {yogurt, cat food}:  sup = 0.006
# {other vegetables, cat food}:  sup = 0.007
# {whole milk, cat food}:  sup = 0.009
# {specialty chocolate}:  sup = 0.03
# {soda, specialty chocolate}:  sup = 0.006
# {rolls/buns, specialty chocolate}:  sup = 0.006
# {other vegetables, specialty chocolate}:  sup = 0.006
# {whole milk, specialty chocolate}:  sup = 0.008
# {waffles}:  sup = 0.038
# {yogurt, waffles}:  sup = 0.008
# {soda, waffles}:  sup = 0.01
# {pastry, waffles}:  sup = 0.007
# {whipped/sour cream, waffles}:  sup = 0.005
# {rolls/buns, waffles}:  sup = 0.009
# {chocolate, waffles}:  sup = 0.006
# {root vegetables, waffles}:  sup = 0.007
# {shopping bags, waffles}:  sup = 0.005
# {other vegetables, waffles}:  sup = 0.01
# {tropical fruit, waffles}:  sup = 0.006
# {whole milk, waffles}:  sup = 0.013
# {bottled water}:  sup = 0.111
# {yogurt, bottled water}:  sup = 0.023
# {whole milk, yogurt, bottled water}:  sup = 0.01
# {other vegetables, yogurt, bottled water}:  sup = 0.008
# {soda, yogurt, bottled water}:  sup = 0.007
# {rolls/buns, yogurt, bottled water}:  sup = 0.007
# {other vegetables, bottled water}:  sup = 0.025
# {whole milk, other vegetables, bottled water}:  sup = 0.011
# {soda, bottled water}:  sup = 0.029
# {whole milk, soda, bottled water}:  sup = 0.008
# {other vegetables, soda, bottled water}:  sup = 0.006
# {rolls/buns, soda, bottled water}:  sup = 0.007
# {whole milk, bottled water}:  sup = 0.034
# {rolls/buns, bottled water}:  sup = 0.024
# {other vegetables, rolls/buns, bottled water}:  sup = 0.007
# {whole milk, rolls/buns, bottled water}:  sup = 0.009
# {finished products}:  sup = 0.007
# {pork}:  sup = 0.058
# {yogurt, pork}:  sup = 0.01
# {soda, pork}:  sup = 0.012
# {pastry, pork}:  sup = 0.006
# {bottled beer, pork}:  sup = 0.005
# {whipped/sour cream, pork}:  sup = 0.008
# {newspapers, pork}:  sup = 0.007
# {margarine, pork}:  sup = 0.006
# {citrus fruit, pork}:  sup = 0.007
# {rolls/buns, pork}:  sup = 0.011
# {whole milk, rolls/buns, pork}:  sup = 0.006
# {other vegetables, rolls/buns, pork}:  sup = 0.006
# {bottled water, pork}:  sup = 0.007
# {root vegetables, pork}:  sup = 0.014
# {other vegetables, root vegetables, pork}:  sup = 0.007
# {whole milk, root vegetables, pork}:  sup = 0.007
# {frankfurter, pork}:  sup = 0.006
# {shopping bags, pork}:  sup = 0.006
# {pip fruit, pork}:  sup = 0.006
# {domestic eggs, pork}:  sup = 0.006
# {sausage, pork}:  sup = 0.007
# {other vegetables, pork}:  sup = 0.022
# {whole milk, other vegetables, pork}:  sup = 0.01
# {brown bread, pork}:  sup = 0.006
# {tropical fruit, pork}:  sup = 0.009
# {whole milk, pork}:  sup = 0.022
# {misc. beverages}:  sup = 0.028
# {soda, misc. beverages}:  sup = 0.007
# {bottled water, misc. beverages}:  sup = 0.005
# {other vegetables, misc. beverages}:  sup = 0.006
# {whole milk, misc. beverages}:  sup = 0.007
# {instant coffee}:  sup = 0.007
# {pip fruit}:  sup = 0.076
# {yogurt, pip fruit}:  sup = 0.018
# {whole milk, yogurt, pip fruit}:  sup = 0.01
# {other vegetables, yogurt, pip fruit}:  sup = 0.008
# {whole milk, other vegetables, yogurt, pip fruit}:  sup = 0.005
# {newspapers, pip fruit}:  sup = 0.007
# {soda, pip fruit}:  sup = 0.013
# {root vegetables, pip fruit}:  sup = 0.016
# {yogurt, root vegetables, pip fruit}:  sup = 0.005
# {other vegetables, root vegetables, pip fruit}:  sup = 0.008
# {whole milk, other vegetables, root vegetables, pip fruit}:  sup = 0.005
# {whole milk, root vegetables, pip fruit}:  sup = 0.009
# {shopping bags, pip fruit}:  sup = 0.009
# {bottled beer, pip fruit}:  sup = 0.006
# {pastry, pip fruit}:  sup = 0.011
# {whole milk, pastry, pip fruit}:  sup = 0.005
# {sausage, pip fruit}:  sup = 0.011
# {whole milk, sausage, pip fruit}:  sup = 0.006
# {other vegetables, pip fruit}:  sup = 0.026
# {whole milk, other vegetables, pip fruit}:  sup = 0.014
# {tropical fruit, pip fruit}:  sup = 0.02
# {yogurt, tropical fruit, pip fruit}:  sup = 0.006
# {other vegetables, tropical fruit, pip fruit}:  sup = 0.009
# {root vegetables, tropical fruit, pip fruit}:  sup = 0.005
# {whole milk, tropical fruit, pip fruit}:  sup = 0.008
# {whole milk, pip fruit}:  sup = 0.03
# {bottled water, pip fruit}:  sup = 0.011
# {citrus fruit, pip fruit}:  sup = 0.014
# {other vegetables, citrus fruit, pip fruit}:  sup = 0.006
# {tropical fruit, citrus fruit, pip fruit}:  sup = 0.006
# {whole milk, citrus fruit, pip fruit}:  sup = 0.005
# {rolls/buns, pip fruit}:  sup = 0.014
# {whole milk, rolls/buns, pip fruit}:  sup = 0.006
# {other vegetables, rolls/buns, pip fruit}:  sup = 0.005
# {oil}:  sup = 0.028
# {yogurt, oil}:  sup = 0.005
# {rolls/buns, oil}:  sup = 0.005
# {root vegetables, oil}:  sup = 0.007
# {other vegetables, oil}:  sup = 0.01
# {whole milk, other vegetables, oil}:  sup = 0.005
# {whole milk, oil}:  sup = 0.011
# {specialty cheese}:  sup = 0.009
# {kitchen towels}:  sup = 0.006
# {processed cheese}:  sup = 0.017
# {soda, processed cheese}:  sup = 0.005
# {other vegetables, processed cheese}:  sup = 0.005
# {whole milk, processed cheese}:  sup = 0.007
# {other vegetables}:  sup = 0.193
# {whole milk, other vegetables}:  sup = 0.075
# {spread cheese}:  sup = 0.011
# {chocolate}:  sup = 0.05
# {yogurt, chocolate}:  sup = 0.009
# {tropical fruit, chocolate}:  sup = 0.008
# {soda, chocolate}:  sup = 0.014
# {whole milk, soda, chocolate}:  sup = 0.005
# {newspapers, chocolate}:  sup = 0.005
# {fruit/vegetable juice, chocolate}:  sup = 0.007
# {bottled water, chocolate}:  sup = 0.006
# {citrus fruit, chocolate}:  sup = 0.006
# {rolls/buns, chocolate}:  sup = 0.012
# {root vegetables, chocolate}:  sup = 0.006
# {shopping bags, chocolate}:  sup = 0.008
# {pip fruit, chocolate}:  sup = 0.006
# {pastry, chocolate}:  sup = 0.008
# {butter, chocolate}:  sup = 0.006
# {sausage, chocolate}:  sup = 0.007
# {other vegetables, chocolate}:  sup = 0.013
# {whole milk, other vegetables, chocolate}:  sup = 0.005
# {whole milk, chocolate}:  sup = 0.017
# {condensed milk}:  sup = 0.01
# {dish cleaner}:  sup = 0.01
# {specialty bar}:  sup = 0.027
# {soda, specialty bar}:  sup = 0.007
# {rolls/buns, specialty bar}:  sup = 0.006
# {other vegetables, specialty bar}:  sup = 0.006
# {whole milk, specialty bar}:  sup = 0.007
# {cream cheese}:  sup = 0.04
# {yogurt, cream cheese}:  sup = 0.012
# {whole milk, yogurt, cream cheese}:  sup = 0.007
# {other vegetables, yogurt, cream cheese}:  sup = 0.005
# {soda, cream cheese}:  sup = 0.007
# {whipped/sour cream, cream cheese}:  sup = 0.006
# {curd, cream cheese}:  sup = 0.005
# {fruit/vegetable juice, cream cheese}:  sup = 0.006
# {citrus fruit, cream cheese}:  sup = 0.006
# {rolls/buns, cream cheese}:  sup = 0.01
# {bottled water, cream cheese}:  sup = 0.006
# {root vegetables, cream cheese}:  sup = 0.008
# {shopping bags, cream cheese}:  sup = 0.006
# {pip fruit, cream cheese}:  sup = 0.006
# {domestic eggs, cream cheese}:  sup = 0.005
# {sausage, cream cheese}:  sup = 0.006
# {other vegetables, cream cheese}:  sup = 0.014
# {whole milk, other vegetables, cream cheese}:  sup = 0.007
# {tropical fruit, cream cheese}:  sup = 0.007
# {whole milk, cream cheese}:  sup = 0.016
# {dental care}:  sup = 0.006
# {vinegar}:  sup = 0.007
# {dog food}:  sup = 0.009
# {beef}:  sup = 0.052
# {yogurt, beef}:  sup = 0.012
# {other vegetables, yogurt, beef}:  sup = 0.005
# {whole milk, yogurt, beef}:  sup = 0.006
# {soda, beef}:  sup = 0.008
# {pastry, beef}:  sup = 0.006
# {whipped/sour cream, beef}:  sup = 0.007
# {newspapers, beef}:  sup = 0.006
# {fruit/vegetable juice, beef}:  sup = 0.005
# {bottled water, beef}:  sup = 0.006
# {citrus fruit, beef}:  sup = 0.008
# {rolls/buns, beef}:  sup = 0.014
# {whole milk, rolls/buns, beef}:  sup = 0.007
# {other vegetables, rolls/buns, beef}:  sup = 0.006
# {pork, beef}:  sup = 0.008
# {root vegetables, beef}:  sup = 0.017
# {other vegetables, root vegetables, beef}:  sup = 0.008
# {whole milk, root vegetables, beef}:  sup = 0.008
# {domestic eggs, beef}:  sup = 0.006
# {butter, beef}:  sup = 0.006
# {margarine, beef}:  sup = 0.006
# {sausage, beef}:  sup = 0.006
# {other vegetables, beef}:  sup = 0.02
# {whole milk, other vegetables, beef}:  sup = 0.009
# {tropical fruit, beef}:  sup = 0.008
# {whole milk, beef}:  sup = 0.021
# {photo/film}:  sup = 0.009
# {domestic eggs}:  sup = 0.063
# {yogurt, domestic eggs}:  sup = 0.014
# {whole milk, yogurt, domestic eggs}:  sup = 0.008
# {other vegetables, yogurt, domestic eggs}:  sup = 0.006
# {soda, domestic eggs}:  sup = 0.012
# {whole milk, soda, domestic eggs}:  sup = 0.005
# {other vegetables, soda, domestic eggs}:  sup = 0.005
# {pastry, domestic eggs}:  sup = 0.009
# {shopping bags, domestic eggs}:  sup = 0.009
# {root vegetables, domestic eggs}:  sup = 0.014
# {other vegetables, root vegetables, domestic eggs}:  sup = 0.007
# {whole milk, root vegetables, domestic eggs}:  sup = 0.009
# {whipped/sour cream, domestic eggs}:  sup = 0.01
# {other vegetables, whipped/sour cream, domestic eggs}:  sup = 0.005
# {whole milk, whipped/sour cream, domestic eggs}:  sup = 0.006
# {newspapers, domestic eggs}:  sup = 0.007
# {sausage, domestic eggs}:  sup = 0.01
# {other vegetables, domestic eggs}:  sup = 0.022
# {whole milk, other vegetables, domestic eggs}:  sup = 0.012
# {brown bread, domestic eggs}:  sup = 0.007
# {tropical fruit, domestic eggs}:  sup = 0.011
# {whole milk, tropical fruit, domestic eggs}:  sup = 0.007
# {pip fruit, domestic eggs}:  sup = 0.009
# {whole milk, pip fruit, domestic eggs}:  sup = 0.005
# {fruit/vegetable juice, domestic eggs}:  sup = 0.008
# {whole milk, domestic eggs}:  sup = 0.03
# {bottled water, domestic eggs}:  sup = 0.009
# {citrus fruit, domestic eggs}:  sup = 0.01
# {whole milk, citrus fruit, domestic eggs}:  sup = 0.006
# {rolls/buns, domestic eggs}:  sup = 0.016
# {whole milk, rolls/buns, domestic eggs}:  sup = 0.007
# {other vegetables, rolls/buns, domestic eggs}:  sup = 0.006
# {pet care}:  sup = 0.009
# {cake bar}:  sup = 0.013
# {whole milk, cake bar}:  sup = 0.006
# {soda}:  sup = 0.174
# {whole milk, soda}:  sup = 0.04
# {other vegetables, soda}:  sup = 0.033
# {whole milk, other vegetables, soda}:  sup = 0.014
# {rolls/buns, soda}:  sup = 0.038
# {whole milk, rolls/buns, soda}:  sup = 0.009
# {other vegetables, rolls/buns, soda}:  sup = 0.01
# {pastry}:  sup = 0.089
# {yogurt, pastry}:  sup = 0.018
# {rolls/buns, yogurt, pastry}:  sup = 0.006
# {whole milk, yogurt, pastry}:  sup = 0.009
# {other vegetables, yogurt, pastry}:  sup = 0.007
# {other vegetables, pastry}:  sup = 0.023
# {whole milk, other vegetables, pastry}:  sup = 0.011
# {tropical fruit, pastry}:  sup = 0.013
# {other vegetables, tropical fruit, pastry}:  sup = 0.005
# {whole milk, tropical fruit, pastry}:  sup = 0.007
# {soda, pastry}:  sup = 0.021
# {whole milk, soda, pastry}:  sup = 0.008
# {other vegetables, soda, pastry}:  sup = 0.005
# {rolls/buns, soda, pastry}:  sup = 0.005
# {root vegetables, pastry}:  sup = 0.011
# {other vegetables, root vegetables, pastry}:  sup = 0.006
# {whole milk, root vegetables, pastry}:  sup = 0.006
# {shopping bags, pastry}:  sup = 0.012
# {sausage, pastry}:  sup = 0.013
# {whole milk, sausage, pastry}:  sup = 0.006
# {whole milk, pastry}:  sup = 0.033
# {bottled water, pastry}:  sup = 0.009
# {rolls/buns, pastry}:  sup = 0.021
# {whole milk, rolls/buns, pastry}:  sup = 0.009
# {other vegetables, rolls/buns, pastry}:  sup = 0.006
# {candy}:  sup = 0.03
# {yogurt, candy}:  sup = 0.005
# {soda, candy}:  sup = 0.009
# {rolls/buns, candy}:  sup = 0.007
# {tropical fruit, candy}:  sup = 0.005
# {other vegetables, candy}:  sup = 0.007
# {whole milk, candy}:  sup = 0.008
# {rice}:  sup = 0.008
# {sweet spreads}:  sup = 0.009
# {red/blush wine}:  sup = 0.019
# {sauces}:  sup = 0.005
# {flour}:  sup = 0.017
# {other vegetables, flour}:  sup = 0.006
# {whole milk, flour}:  sup = 0.008
# {white bread}:  sup = 0.042
# {yogurt, white bread}:  sup = 0.009
# {tropical fruit, white bread}:  sup = 0.009
# {soda, white bread}:  sup = 0.01
# {pastry, white bread}:  sup = 0.006
# {whipped/sour cream, white bread}:  sup = 0.005
# {fruit/vegetable juice, white bread}:  sup = 0.007
# {rolls/buns, white bread}:  sup = 0.007
# {root vegetables, white bread}:  sup = 0.008
# {frankfurter, white bread}:  sup = 0.005
# {shopping bags, white bread}:  sup = 0.007
# {pip fruit, white bread}:  sup = 0.007
# {domestic eggs, white bread}:  sup = 0.006
# {sausage, white bread}:  sup = 0.007
# {other vegetables, white bread}:  sup = 0.014
# {whole milk, other vegetables, white bread}:  sup = 0.006
# {whole milk, white bread}:  sup = 0.017
# {grapes}:  sup = 0.022
# {tropical fruit, grapes}:  sup = 0.006
# {other vegetables, grapes}:  sup = 0.009
# {whole milk, grapes}:  sup = 0.007
# {jam}:  sup = 0.005
# {root vegetables}:  sup = 0.109
# {other vegetables, root vegetables}:  sup = 0.047
# {whole milk, other vegetables, root vegetables}:  sup = 0.023
# {soda, root vegetables}:  sup = 0.019
# {whole milk, soda, root vegetables}:  sup = 0.008
# {other vegetables, soda, root vegetables}:  sup = 0.008
# {yogurt, root vegetables}:  sup = 0.026
# {whole milk, yogurt, root vegetables}:  sup = 0.015
# {other vegetables, yogurt, root vegetables}:  sup = 0.013
# {whole milk, other vegetables, yogurt, root vegetables}:  sup = 0.008
# {rolls/buns, yogurt, root vegetables}:  sup = 0.007
# {whole milk, root vegetables}:  sup = 0.049
# {bottled water, root vegetables}:  sup = 0.016
# {other vegetables, bottled water, root vegetables}:  sup = 0.007
# {whole milk, bottled water, root vegetables}:  sup = 0.007
# {rolls/buns, root vegetables}:  sup = 0.024
# {other vegetables, rolls/buns, root vegetables}:  sup = 0.012
# {whole milk, other vegetables, rolls/buns, root vegetables}:  sup = 0.006
# {whole milk, rolls/buns, root vegetables}:  sup = 0.013
# {frankfurter}:  sup = 0.059
# {root vegetables, frankfurter}:  sup = 0.01
# {whole milk, root vegetables, frankfurter}:  sup = 0.005
# {soda, frankfurter}:  sup = 0.011
# {sausage, frankfurter}:  sup = 0.01
# {shopping bags, frankfurter}:  sup = 0.008
# {pip fruit, frankfurter}:  sup = 0.007
# {bottled beer, frankfurter}:  sup = 0.005
# {domestic eggs, frankfurter}:  sup = 0.007
# {yogurt, frankfurter}:  sup = 0.011
# {whole milk, yogurt, frankfurter}:  sup = 0.006
# {whipped/sour cream, frankfurter}:  sup = 0.006
# {other vegetables, frankfurter}:  sup = 0.016
# {whole milk, other vegetables, frankfurter}:  sup = 0.008
# {brown bread, frankfurter}:  sup = 0.007
# {tropical fruit, frankfurter}:  sup = 0.009
# {whole milk, tropical fruit, frankfurter}:  sup = 0.005
# {pastry, frankfurter}:  sup = 0.008
# {fruit/vegetable juice, frankfurter}:  sup = 0.005
# {whole milk, frankfurter}:  sup = 0.021
# {bottled water, frankfurter}:  sup = 0.007
# {citrus fruit, frankfurter}:  sup = 0.007
# {rolls/buns, frankfurter}:  sup = 0.019
# {other vegetables, rolls/buns, frankfurter}:  sup = 0.006
# {whole milk, rolls/buns, frankfurter}:  sup = 0.006
# {candles}:  sup = 0.009
# {cleaner}:  sup = 0.005
# {liquor}:  sup = 0.011
# {frozen vegetables}:  sup = 0.048
# {yogurt, frozen vegetables}:  sup = 0.012
# {whole milk, yogurt, frozen vegetables}:  sup = 0.006
# {other vegetables, yogurt, frozen vegetables}:  sup = 0.005
# {soda, frozen vegetables}:  sup = 0.009
# {whipped/sour cream, frozen vegetables}:  sup = 0.008
# {fruit/vegetable juice, frozen vegetables}:  sup = 0.008
# {margarine, frozen vegetables}:  sup = 0.005
# {citrus fruit, frozen vegetables}:  sup = 0.007
# {rolls/buns, frozen vegetables}:  sup = 0.01
# {whole milk, rolls/buns, frozen vegetables}:  sup = 0.005
# {pork, frozen vegetables}:  sup = 0.006
# {bottled water, frozen vegetables}:  sup = 0.006
# {root vegetables, frozen vegetables}:  sup = 0.012
# {other vegetables, root vegetables, frozen vegetables}:  sup = 0.006
# {whole milk, root vegetables, frozen vegetables}:  sup = 0.006
# {frankfurter, frozen vegetables}:  sup = 0.005
# {pip fruit, frozen vegetables}:  sup = 0.007
# {domestic eggs, frozen vegetables}:  sup = 0.005
# {butter, frozen vegetables}:  sup = 0.006
# {sausage, frozen vegetables}:  sup = 0.006
# {other vegetables, frozen vegetables}:  sup = 0.018
# {whole milk, other vegetables, frozen vegetables}:  sup = 0.01
# {tropical fruit, frozen vegetables}:  sup = 0.009
# {whole milk, frozen vegetables}:  sup = 0.02
# {butter}:  sup = 0.055
# {yogurt, butter}:  sup = 0.015
# {whole milk, yogurt, butter}:  sup = 0.009
# {other vegetables, yogurt, butter}:  sup = 0.006
# {soda, butter}:  sup = 0.009
# {pastry, butter}:  sup = 0.008
# {bottled beer, butter}:  sup = 0.006
# {whipped/sour cream, butter}:  sup = 0.01
# {other vegetables, whipped/sour cream, butter}:  sup = 0.006
# {whole milk, whipped/sour cream, butter}:  sup = 0.007
# {newspapers, butter}:  sup = 0.006
# {fruit/vegetable juice, butter}:  sup = 0.008
# {margarine, butter}:  sup = 0.007
# {citrus fruit, butter}:  sup = 0.009
# {whole milk, citrus fruit, butter}:  sup = 0.005
# {rolls/buns, butter}:  sup = 0.013
# {other vegetables, rolls/buns, butter}:  sup = 0.006
# {whole milk, rolls/buns, butter}:  sup = 0.007
# {pork, butter}:  sup = 0.005
# {bottled water, butter}:  sup = 0.009
# {whole milk, bottled water, butter}:  sup = 0.005
# {root vegetables, butter}:  sup = 0.013
# {other vegetables, root vegetables, butter}:  sup = 0.007
# {whole milk, root vegetables, butter}:  sup = 0.008
# {pip fruit, butter}:  sup = 0.007
# {domestic eggs, butter}:  sup = 0.01
# {whole milk, domestic eggs, butter}:  sup = 0.006
# {sausage, butter}:  sup = 0.009
# {other vegetables, butter}:  sup = 0.02
# {whole milk, other vegetables, butter}:  sup = 0.011
# {brown bread, butter}:  sup = 0.006
# {tropical fruit, butter}:  sup = 0.01
# {other vegetables, tropical fruit, butter}:  sup = 0.005
# {whole milk, tropical fruit, butter}:  sup = 0.006
# {whole milk, butter}:  sup = 0.028
# {citrus fruit}:  sup = 0.083
# {yogurt, citrus fruit}:  sup = 0.022
# {whole milk, yogurt, citrus fruit}:  sup = 0.01
# {other vegetables, yogurt, citrus fruit}:  sup = 0.008
# {rolls/buns, yogurt, citrus fruit}:  sup = 0.006
# {soda, citrus fruit}:  sup = 0.013
# {pastry, citrus fruit}:  sup = 0.01
# {shopping bags, citrus fruit}:  sup = 0.01
# {root vegetables, citrus fruit}:  sup = 0.018
# {other vegetables, root vegetables, citrus fruit}:  sup = 0.01
# {whole milk, other vegetables, root vegetables, citrus fruit}:  sup = 0.006
# {whole milk, root vegetables, citrus fruit}:  sup = 0.009
# {sausage, citrus fruit}:  sup = 0.011
# {other vegetables, citrus fruit}:  sup = 0.029
# {whole milk, other vegetables, citrus fruit}:  sup = 0.013
# {tropical fruit, citrus fruit}:  sup = 0.02
# {yogurt, tropical fruit, citrus fruit}:  sup = 0.006
# {other vegetables, tropical fruit, citrus fruit}:  sup = 0.009
# {root vegetables, tropical fruit, citrus fruit}:  sup = 0.006
# {whole milk, tropical fruit, citrus fruit}:  sup = 0.009
# {whole milk, citrus fruit}:  sup = 0.031
# {bottled water, citrus fruit}:  sup = 0.014
# {other vegetables, bottled water, citrus fruit}:  sup = 0.005
# {whole milk, bottled water, citrus fruit}:  sup = 0.006
# {rolls/buns, citrus fruit}:  sup = 0.017
# {whole milk, rolls/buns, citrus fruit}:  sup = 0.007
# {other vegetables, rolls/buns, citrus fruit}:  sup = 0.006
# {dessert}:  sup = 0.037
# {fruit/vegetable juice, dessert}:  sup = 0.006
# {yogurt, dessert}:  sup = 0.01
# {soda, dessert}:  sup = 0.01
# {curd, dessert}:  sup = 0.005
# {tropical fruit, dessert}:  sup = 0.006
# {bottled water, dessert}:  sup = 0.005
# {rolls/buns, dessert}:  sup = 0.007
# {root vegetables, dessert}:  sup = 0.006
# {shopping bags, dessert}:  sup = 0.006
# {pastry, dessert}:  sup = 0.005
# {sausage, dessert}:  sup = 0.006
# {other vegetables, dessert}:  sup = 0.012
# {whole milk, dessert}:  sup = 0.014
# {sausage}:  sup = 0.094
# {other vegetables, sausage}:  sup = 0.027
# {whole milk, other vegetables, sausage}:  sup = 0.01
# {tropical fruit, sausage}:  sup = 0.014
# {other vegetables, tropical fruit, sausage}:  sup = 0.006
# {whole milk, tropical fruit, sausage}:  sup = 0.007
# {soda, sausage}:  sup = 0.024
# {whole milk, soda, sausage}:  sup = 0.007
# {other vegetables, soda, sausage}:  sup = 0.007
# {rolls/buns, soda, sausage}:  sup = 0.01
# {yogurt, sausage}:  sup = 0.02
# {whole milk, yogurt, sausage}:  sup = 0.009
# {soda, yogurt, sausage}:  sup = 0.006
# {other vegetables, yogurt, sausage}:  sup = 0.008
# {rolls/buns, yogurt, sausage}:  sup = 0.006
# {shopping bags, sausage}:  sup = 0.016
# {other vegetables, shopping bags, sausage}:  sup = 0.005
# {soda, shopping bags, sausage}:  sup = 0.006
# {rolls/buns, shopping bags, sausage}:  sup = 0.006
# {root vegetables, sausage}:  sup = 0.015
# {yogurt, root vegetables, sausage}:  sup = 0.005
# {other vegetables, root vegetables, sausage}:  sup = 0.007
# {whole milk, root vegetables, sausage}:  sup = 0.008
# {whole milk, sausage}:  sup = 0.03
# {bottled water, sausage}:  sup = 0.012
# {other vegetables, bottled water, sausage}:  sup = 0.005
# {rolls/buns, sausage}:  sup = 0.031
# {whole milk, rolls/buns, sausage}:  sup = 0.009
# {other vegetables, rolls/buns, sausage}:  sup = 0.009
# {frozen fish}:  sup = 0.012
# {tropical fruit}:  sup = 0.105
# {yogurt, tropical fruit}:  sup = 0.029
# {rolls/buns, yogurt, tropical fruit}:  sup = 0.009
# {whole milk, yogurt, tropical fruit}:  sup = 0.015
# {other vegetables, yogurt, tropical fruit}:  sup = 0.012
# {whole milk, other vegetables, yogurt, tropical fruit}:  sup = 0.008
# {soda, yogurt, tropical fruit}:  sup = 0.007
# {other vegetables, tropical fruit}:  sup = 0.036
# {whole milk, other vegetables, tropical fruit}:  sup = 0.017
# {soda, tropical fruit}:  sup = 0.021
# {rolls/buns, soda, tropical fruit}:  sup = 0.005
# {whole milk, soda, tropical fruit}:  sup = 0.008
# {other vegetables, soda, tropical fruit}:  sup = 0.007
# {root vegetables, tropical fruit}:  sup = 0.021
# {other vegetables, root vegetables, tropical fruit}:  sup = 0.012
# {whole milk, other vegetables, root vegetables, tropical fruit}:  sup = 0.007
# {yogurt, root vegetables, tropical fruit}:  sup = 0.008
# {whole milk, yogurt, root vegetables, tropical fruit}:  sup = 0.006
# {whole milk, root vegetables, tropical fruit}:  sup = 0.012
# {rolls/buns, root vegetables, tropical fruit}:  sup = 0.006
# {whole milk, tropical fruit}:  sup = 0.042
# {bottled water, tropical fruit}:  sup = 0.019
# {yogurt, bottled water, tropical fruit}:  sup = 0.007
# {other vegetables, bottled water, tropical fruit}:  sup = 0.006
# {soda, bottled water, tropical fruit}:  sup = 0.005
# {whole milk, bottled water, tropical fruit}:  sup = 0.008
# {rolls/buns, bottled water, tropical fruit}:  sup = 0.005
# {rolls/buns, tropical fruit}:  sup = 0.025
# {other vegetables, rolls/buns, tropical fruit}:  sup = 0.008
# {whole milk, rolls/buns, tropical fruit}:  sup = 0.011
# {pot plants}:  sup = 0.017
# {whole milk, pot plants}:  sup = 0.007
# {meat}:  sup = 0.026
# {yogurt, meat}:  sup = 0.005
# {soda, meat}:  sup = 0.005
# {rolls/buns, meat}:  sup = 0.007
# {root vegetables, meat}:  sup = 0.005
# {sausage, meat}:  sup = 0.005
# {other vegetables, meat}:  sup = 0.01
# {whole milk, meat}:  sup = 0.01
# {sugar}:  sup = 0.034
# {yogurt, sugar}:  sup = 0.007
# {soda, sugar}:  sup = 0.007
# {pastry, sugar}:  sup = 0.005
# {rolls/buns, sugar}:  sup = 0.007
# {root vegetables, sugar}:  sup = 0.006
# {whole milk, sugar}:  sup = 0.015
# {margarine, sugar}:  sup = 0.005
# {other vegetables, sugar}:  sup = 0.011
# {whole milk, other vegetables, sugar}:  sup = 0.006
# {canned fish}:  sup = 0.015
# {other vegetables, canned fish}:  sup = 0.005
# {herbs}:  sup = 0.016
# {root vegetables, herbs}:  sup = 0.007
# {other vegetables, herbs}:  sup = 0.008
# {whole milk, herbs}:  sup = 0.008
# {pickled vegetables}:  sup = 0.018
# {other vegetables, pickled vegetables}:  sup = 0.006
# {whole milk, pickled vegetables}:  sup = 0.007
# {Instant food products}:  sup = 0.008
# {hard cheese}:  sup = 0.025
# {yogurt, hard cheese}:  sup = 0.006
# {rolls/buns, hard cheese}:  sup = 0.006
# {root vegetables, hard cheese}:  sup = 0.006
# {sausage, hard cheese}:  sup = 0.005
# {other vegetables, hard cheese}:  sup = 0.009
# {whole milk, hard cheese}:  sup = 0.01
# {liver loaf}:  sup = 0.005
# {whipped/sour cream}:  sup = 0.072
# {root vegetables, whipped/sour cream}:  sup = 0.017
# {other vegetables, root vegetables, whipped/sour cream}:  sup = 0.009
# {whole milk, other vegetables, root vegetables, whipped/sour cream}:  sup = 0.005
# {yogurt, root vegetables, whipped/sour cream}:  sup = 0.006
# {whole milk, root vegetables, whipped/sour cream}:  sup = 0.009
# {newspapers, whipped/sour cream}:  sup = 0.007
# {soda, whipped/sour cream}:  sup = 0.012
# {whole milk, soda, whipped/sour cream}:  sup = 0.005
# {yogurt, whipped/sour cream}:  sup = 0.021
# {whole milk, yogurt, whipped/sour cream}:  sup = 0.011
# {other vegetables, yogurt, whipped/sour cream}:  sup = 0.01
# {whole milk, other vegetables, yogurt, whipped/sour cream}:  sup = 0.006
# {shopping bags, whipped/sour cream}:  sup = 0.008
# {pip fruit, whipped/sour cream}:  sup = 0.009
# {other vegetables, pip fruit, whipped/sour cream}:  sup = 0.006
# {whole milk, pip fruit, whipped/sour cream}:  sup = 0.006
# {pastry, whipped/sour cream}:  sup = 0.008
# {sausage, whipped/sour cream}:  sup = 0.009
# {whole milk, sausage, whipped/sour cream}:  sup = 0.005
# {other vegetables, whipped/sour cream}:  sup = 0.029
# {whole milk, other vegetables, whipped/sour cream}:  sup = 0.015
# {tropical fruit, whipped/sour cream}:  sup = 0.014
# {yogurt, tropical fruit, whipped/sour cream}:  sup = 0.006
# {other vegetables, tropical fruit, whipped/sour cream}:  sup = 0.008
# {whole milk, tropical fruit, whipped/sour cream}:  sup = 0.008
# {fruit/vegetable juice, whipped/sour cream}:  sup = 0.009
# {whole milk, whipped/sour cream}:  sup = 0.032
# {bottled water, whipped/sour cream}:  sup = 0.009
# {citrus fruit, whipped/sour cream}:  sup = 0.011
# {other vegetables, citrus fruit, whipped/sour cream}:  sup = 0.006
# {whole milk, citrus fruit, whipped/sour cream}:  sup = 0.006
# {rolls/buns, whipped/sour cream}:  sup = 0.015
# {other vegetables, rolls/buns, whipped/sour cream}:  sup = 0.007
# {whole milk, rolls/buns, whipped/sour cream}:  sup = 0.008
# {curd}:  sup = 0.053
# {yogurt, curd}:  sup = 0.017
# {whole milk, yogurt, curd}:  sup = 0.01
# {other vegetables, yogurt, curd}:  sup = 0.006
# {soda, curd}:  sup = 0.008
# {pastry, curd}:  sup = 0.008
# {whipped/sour cream, curd}:  sup = 0.01
# {whole milk, whipped/sour cream, curd}:  sup = 0.006
# {newspapers, curd}:  sup = 0.006
# {margarine, curd}:  sup = 0.006
# {citrus fruit, curd}:  sup = 0.007
# {rolls/buns, curd}:  sup = 0.01
# {whole milk, rolls/buns, curd}:  sup = 0.006
# {bottled water, curd}:  sup = 0.006
# {root vegetables, curd}:  sup = 0.011
# {other vegetables, root vegetables, curd}:  sup = 0.005
# {whole milk, root vegetables, curd}:  sup = 0.006
# {shopping bags, curd}:  sup = 0.005
# {pip fruit, curd}:  sup = 0.008
# {domestic eggs, curd}:  sup = 0.007
# {butter, curd}:  sup = 0.007
# {sausage, curd}:  sup = 0.008
# {other vegetables, curd}:  sup = 0.017
# {whole milk, other vegetables, curd}:  sup = 0.01
# {tropical fruit, curd}:  sup = 0.01
# {yogurt, tropical fruit, curd}:  sup = 0.005
# {other vegetables, tropical fruit, curd}:  sup = 0.005
# {whole milk, tropical fruit, curd}:  sup = 0.007
# {whole milk, curd}:  sup = 0.026
# {onions}:  sup = 0.031
# {yogurt, onions}:  sup = 0.007
# {soda, onions}:  sup = 0.005
# {whipped/sour cream, onions}:  sup = 0.005
# {bottled water, onions}:  sup = 0.006
# {citrus fruit, onions}:  sup = 0.006
# {rolls/buns, onions}:  sup = 0.007
# {root vegetables, onions}:  sup = 0.009
# {other vegetables, root vegetables, onions}:  sup = 0.006
# {other vegetables, onions}:  sup = 0.014
# {whole milk, other vegetables, onions}:  sup = 0.007
# {tropical fruit, onions}:  sup = 0.006
# {whole milk, onions}:  sup = 0.012
# {house keeping products}:  sup = 0.008
# {roll products}:  sup = 0.01
# {salt}:  sup = 0.011
# {female sanitary products}:  sup = 0.006
# {chocolate marshmallow}:  sup = 0.009
# {curd cheese}:  sup = 0.005
# {shopping bags}:  sup = 0.099
# {yogurt, shopping bags}:  sup = 0.015
# {whole milk, yogurt, shopping bags}:  sup = 0.005
# {other vegetables, yogurt, shopping bags}:  sup = 0.005
# {other vegetables, shopping bags}:  sup = 0.023
# {whole milk, other vegetables, shopping bags}:  sup = 0.008
# {tropical fruit, shopping bags}:  sup = 0.014
# {soda, shopping bags}:  sup = 0.025
# {other vegetables, soda, shopping bags}:  sup = 0.005
# {rolls/buns, soda, shopping bags}:  sup = 0.006
# {whole milk, soda, shopping bags}:  sup = 0.007
# {root vegetables, shopping bags}:  sup = 0.013
# {other vegetables, root vegetables, shopping bags}:  sup = 0.007
# {whole milk, root vegetables, shopping bags}:  sup = 0.005
# {whole milk, shopping bags}:  sup = 0.025
# {bottled water, shopping bags}:  sup = 0.011
# {rolls/buns, shopping bags}:  sup = 0.02
# {other vegetables, rolls/buns, shopping bags}:  sup = 0.005
# {whole milk, rolls/buns, shopping bags}:  sup = 0.005
# {baking powder}:  sup = 0.018
# {other vegetables, baking powder}:  sup = 0.007
# {whole milk, baking powder}:  sup = 0.009
# {ice cream}:  sup = 0.025
# {soda, ice cream}:  sup = 0.006
# {other vegetables, ice cream}:  sup = 0.005
# {whole milk, ice cream}:  sup = 0.006
# {sliced cheese}:  sup = 0.025
# {yogurt, sliced cheese}:  sup = 0.008
# {soda, sliced cheese}:  sup = 0.005
# {rolls/buns, sliced cheese}:  sup = 0.008
# {root vegetables, sliced cheese}:  sup = 0.006
# {sausage, sliced cheese}:  sup = 0.007
# {tropical fruit, sliced cheese}:  sup = 0.005
# {other vegetables, sliced cheese}:  sup = 0.009
# {whole milk, sliced cheese}:  sup = 0.011
# {mustard}:  sup = 0.012
# {whole milk, mustard}:  sup = 0.005
# {turkey}:  sup = 0.008
# {frozen potato products}:  sup = 0.008
# {hygiene articles}:  sup = 0.033
# {yogurt, hygiene articles}:  sup = 0.007
# {soda, hygiene articles}:  sup = 0.007
# {bottled water, hygiene articles}:  sup = 0.006
# {citrus fruit, hygiene articles}:  sup = 0.005
# {rolls/buns, hygiene articles}:  sup = 0.006
# {root vegetables, hygiene articles}:  sup = 0.005
# {napkins, hygiene articles}:  sup = 0.006
# {shopping bags, hygiene articles}:  sup = 0.005
# {other vegetables, hygiene articles}:  sup = 0.01
# {whole milk, other vegetables, hygiene articles}:  sup = 0.005
# {tropical fruit, hygiene articles}:  sup = 0.007
# {whole milk, hygiene articles}:  sup = 0.013
# {softener}:  sup = 0.005
# {long life bakery product}:  sup = 0.037
# {yogurt, long life bakery product}:  sup = 0.009
# {tropical fruit, long life bakery product}:  sup = 0.006
# {soda, long life bakery product}:  sup = 0.008
# {pastry, long life bakery product}:  sup = 0.006
# {whipped/sour cream, long life bakery product}:  sup = 0.006
# {fruit/vegetable juice, long life bakery product}:  sup = 0.006
# {rolls/buns, long life bakery product}:  sup = 0.008
# {root vegetables, long life bakery product}:  sup = 0.005
# {shopping bags, long life bakery product}:  sup = 0.005
# {sausage, long life bakery product}:  sup = 0.005
# {other vegetables, long life bakery product}:  sup = 0.011
# {whole milk, other vegetables, long life bakery product}:  sup = 0.006
# {chocolate, long life bakery product}:  sup = 0.005
# {whole milk, long life bakery product}:  sup = 0.014
# {soups}:  sup = 0.007
# {seasonal products}:  sup = 0.014
# {pasta}:  sup = 0.015
# {whole milk, pasta}:  sup = 0.006
# {whole milk}:  sup = 0.256

# %%
# Generate the association rules from a list of frequent itemsets.
H = generate_rules(F, support_data, min_confidence=0.6, verbose=True)
# Out:
# {pip fruit, domestic eggs} ---> {whole milk}:  conf = 0.624, sup = 0.005
# {root vegetables, onions} ---> {other vegetables}:  conf = 0.602, sup = 0.006
# {yogurt, butter} ---> {whole milk}:  conf = 0.639, sup = 0.009
# {domestic eggs, margarine} ---> {whole milk}:  conf = 0.622, sup = 0.005
# {butter, tropical fruit} ---> {whole milk}:  conf = 0.622, sup = 0.006
# {pip fruit, whipped/sour cream} ---> {other vegetables}:  conf = 0.604, sup = 0.006
# {whipped/sour cream, butter} ---> {whole milk}:  conf = 0.66, sup = 0.007
# {root vegetables, butter} ---> {whole milk}:  conf = 0.638, sup = 0.008
# {bottled water, butter} ---> {whole milk}:  conf = 0.602, sup = 0.005
# {curd, tropical fruit} ---> {whole milk}:  conf = 0.634, sup = 0.007
# {domestic eggs, butter} ---> {whole milk}:  conf = 0.621, sup = 0.006
# {pip fruit, whipped/sour cream} ---> {whole milk}:  conf = 0.648, sup = 0.006
# {domestic eggs, tropical fruit} ---> {whole milk}:  conf = 0.607, sup = 0.007
# {yogurt, fruit/vegetable juice, other vegetables} ---> {whole milk}:  conf = 0.617, sup = 0.005
# {root vegetables, whole milk, citrus fruit} ---> {other vegetables}:  conf = 0.633, sup = 0.006
# {root vegetables, other vegetables, whipped/sour cream} ---> {whole milk}:  conf = 0.607, sup = 0.005
# {yogurt, other vegetables, tropical fruit} ---> {whole milk}:  conf = 0.62, sup = 0.008
# {yogurt, other vegetables, pip fruit} ---> {whole milk}:  conf = 0.625, sup = 0.005
# {root vegetables, other vegetables, yogurt} ---> {whole milk}:  conf = 0.606, sup = 0.008
# {root vegetables, whole milk, pip fruit} ---> {other vegetables}:  conf = 0.614, sup = 0.005
# {root vegetables, other vegetables, pip fruit} ---> {whole milk}:  conf = 0.675, sup = 0.005
# {root vegetables, tropical fruit, yogurt} ---> {whole milk}:  conf = 0.7, sup = 0.006

# %% [markdown]
# ## Part 3: Analysis of result
# ### we choose support to be more than 0.05 and confidence more than 0.6, than we find some interesting association rules
# From the results we can know that : {whole milk}:  sup = 0.256, {other vegetables}:  sup = 0.193
# As we filter the association rules with confidence to be more than 0.6. These rules' support are much smaller than their confidence, so we can guarantee that **lift values** of all our generated association rules are all very high about 2~3, which is more than 1. This implies that two occurrences are dependent on one another, and makes those rules potentially useful for predicting the consequent in future data sets.
# Next, we manually analyze the result and the reason of the result
# -  when yogurt or cream appears, the whole milk may also appears. This may because yogurt ,cream and milk are both dairy product, so when people buy milk they also buy yogurt.
# -  when butter appears, the whole milk may also appears. This may be due to the fact that people when people drinking milk they will also eat some bread with butter.
# -  when domestic eggs or fruit appear, the whole milk may also appears. This may be due to fact that the reason that when people choose eggs ,fruit(including tropical fruit, pip fruit, citrus fruit) and milk as dishes for the breakfast.
# -  when fruit appear, the other vegetables may also appears. This may be due to the fact that fruit and vegetables are the ingredients of Salad.
