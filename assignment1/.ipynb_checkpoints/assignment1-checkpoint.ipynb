# %%
import pandas as pd

# %%
# import data
unames = ['user_id', 'gender', 'age', 'occupation', 'zip']
users = pd.read_table('ml-1m/users.dat', sep='::', header=None, names=unames, engine='python')

rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_table('ml-1m/ratings.dat', sep='::', header=None, names=rnames, engine='python')

mnames = ['movie_id', 'title', 'genres']
movies = pd.read_table('ml-1m/movies.dat', sep='::', header=None, names=mnames, engine='python')

# %%
data = pd.merge(pd.merge(ratings, users), movies)

# %%
data[:5]
# Out:
#    user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 0        1      1193       5  978300760      F    1          10  48067
# 1        2      1193       5  978298413      M   56          16  70072
# 2       12      1193       4  978220179      M   25          12  32793
# 3       15      1193       4  978199279      M   25           7  22903
# 4       17      1193       5  978158471      M   50           1  95350
#
#                                     title genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4  One Flew Over the Cuckoo's Nest (1975)  Drama

# %%
# 1.An aggregate of the movie ratings for each particular genre.
mean_ratings_by_genres = data.pivot_table('rating', index='genres', aggfunc='mean')

# %%
mean_ratings_by_genres
# Out:
# genres
# Action                                           3.354886
# Action|Adventure                                 3.676814
# Action|Adventure|Animation                       4.147826
# Action|Adventure|Animation|Children's|Fantasy    2.703704
# Action|Adventure|Animation|Horror|Sci-Fi         3.546926
# Action|Adventure|Children's                      1.318182
# Action|Adventure|Children's|Comedy               2.306950
# Action|Adventure|Children's|Fantasy              2.090909
# Action|Adventure|Children's|Sci-Fi               1.874286
# Action|Adventure|Comedy                          3.095330
# Action|Adventure|Comedy|Crime                    3.137194
# Action|Adventure|Comedy|Horror                   3.826642
# Action|Adventure|Comedy|Horror|Sci-Fi            3.804233
# Action|Adventure|Comedy|Romance                  3.862448
# Action|Adventure|Comedy|Sci-Fi                   3.739953
# Action|Adventure|Comedy|War                      2.276995
# ...

# %%
mean_ratings_by_genres_gender = data.pivot_table('rating', index='genres',columns = 'gender',aggfunc='mean')

# %%
mean_ratings_by_genres_gender[:5]
# Out:
# gender                                                F         M
# genres
# Action                                         3.367474  3.352991
# Action|Adventure                               3.701213  3.671115
# Action|Adventure|Animation                     3.843750  4.217082
# Action|Adventure|Animation|Children's|Fantasy  3.146341  2.510638
# Action|Adventure|Animation|Horror|Sci-Fi       3.422535  3.563071

# %%
# 2.The top 5 highest ranked genre by women.
top_female_ratings_by_genres = mean_ratings_by_genres_gender.sort_values(by='F', ascending=False)

# %%
top_female_ratings_by_genres[:5]
# Out:
# gender                                     F         M
# genres
# Animation|Comedy|Thriller           4.550802  4.445110
# Animation                           4.533333  4.353107
# Film-Noir|Romance|Thriller          4.448718  4.211073
# Sci-Fi|War                          4.376623  4.464789
# Adventure|Children's|Drama|Musical  4.355030  4.203138

# %%
# 3.The top 5 highest ranked genre by men.
top_male_ratings_by_genres = mean_ratings_by_genres_gender.sort_values(by='M', ascending=False)

# %%
top_male_ratings_by_genres[:5]
# Out:
# gender                            F         M
# genres
# Sci-Fi|War                 4.376623  4.464789
# Animation|Comedy|Thriller  4.550802  4.445110
# Film-Noir|Mystery          4.319444  4.381536
# Adventure|War              4.187970  4.376633
# Animation                  4.533333  4.353107

# %%
# 4.A breakdown of a movie’s ratings by age, use any movie of your choice.
# I choose movie:One Flew Over the Cuckoo's Nest (1975) as the example
selectedMovieData = data.ix[data['title'] == 'One Flew Over the Cuckoo\'s Nest (1975)']

# %%
selectedMovieData[:10]
# Out:
#    user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 0        1      1193       5  978300760      F    1          10  48067
# 1        2      1193       5  978298413      M   56          16  70072
# 2       12      1193       4  978220179      M   25          12  32793
# 3       15      1193       4  978199279      M   25           7  22903
# 4       17      1193       5  978158471      M   50           1  95350
# 5       18      1193       4  978156168      F   18           3  95825
# 6       19      1193       5  982730936      M    1          10  48073
# 7       24      1193       5  978136709      F   25           7  10023
# 8       28      1193       3  978125194      F   25           1  14607
# 9       33      1193       5  978557765      M   45           3  55421
#
#                                     title genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# ...

# %%
labels = ['0-9', '10-19', '20-29', '30-39', '40-49', '50-59']

# %%
selectedMovieData.loc[:,('age_group')] = pd.cut(selectedMovieData.age, range(0, 61, 10), right=False, labels=labels)

# %%
selectedMovieData[:10]
# Out:
#    user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 0        1      1193       5  978300760      F    1          10  48067
# 1        2      1193       5  978298413      M   56          16  70072
# 2       12      1193       4  978220179      M   25          12  32793
# 3       15      1193       4  978199279      M   25           7  22903
# 4       17      1193       5  978158471      M   50           1  95350
# 5       18      1193       4  978156168      F   18           3  95825
# 6       19      1193       5  982730936      M    1          10  48073
# 7       24      1193       5  978136709      F   25           7  10023
# 8       28      1193       3  978125194      F   25           1  14607
# 9       33      1193       5  978557765      M   45           3  55421
#
#                                     title genres age_group
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama       0-9
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama     50-59
# ...

# %%
mean_ratings_by_age_group = selectedMovieData.pivot_table('rating', index='age_group', aggfunc='mean')

# %%
mean_ratings_by_age_group
# Out:
# age_group
# 0-9      4.222222
# 10-19    4.457831
# 20-29    4.412371
# 30-39    4.389578
# 40-49    4.319372
# 50-59    4.356061
# Name: rating, dtype: float64

# %%
# 5.A function that given a user_id and movie_id 
# returns a list of user_ids for other users
# that rated the movie identified by the provided movie_id with the same score
def sameUser(user_id, movie_id):
    selectedRating = data[(data.user_id == user_id) & (data.movie_id == movie_id)]['rating'].loc[0]
    sameMovieData = data[(data.movie_id == movie_id) & (data.rating == selectedRating)]
    removedDuplicateSameMovieData = sameMovieData.ix[sameMovieData['user_id']!=user_id]
    return removedDuplicateSameMovieData['user_id'].reset_index(level=0, drop=True)

# %%
# example usage for sameUser function
sameUser(1,1193)[:10]
# Out:
# 0     2
# 1    17
# 2    19
# 3    24
# 4    33
# 5    39
# 6    53
# 7    54
# 8    58
# 9    81
# Name: user_id, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# 6.additional topics:
# (1) Which movies do men and women most disagree on

data.reset_index('movie_id', inplace=True)

# %%
pivoted = data.pivot_table(index=['movie_id', 'title'],
                           columns=['gender'],
                           values='rating',
                           fill_value=0)

# %%
pivoted['diff'] = pivoted.M - pivoted.F

# %%
pivoted[:5]
# Out:
# gender                                              F         M      diff
# movie_id title
# 1        Toy Story (1995)                    4.187817  4.130552 -0.057265
# 2        Jumanji (1995)                      3.278409  3.175238 -0.103171
# 3        Grumpier Old Men (1995)             3.073529  2.994152 -0.079377
# 4        Waiting to Exhale (1995)            2.976471  2.482353 -0.494118
# 5        Father of the Bride Part II (1995)  3.212963  2.888298 -0.324665

# %%
pivoted.reset_index('movie_id', inplace=True)

# %%
most_40 = data.groupby('movie_id').size().sort_values(ascending=False)[:40]

# %%
disagreements = pivoted[pivoted.movie_id.isin(most_40)]['diff']
disagreements.sort_values().plot(kind='barh', figsize=[9, 15])
plt.title('Male vs. Female Avg. Ratings\n(Difference > 0 = Favored by Men)')
plt.ylabel('Title')
plt.xlabel('Average Rating Difference');
plt.show()

# %%
# (2) age distribution among our users
users.age.plot.hist(bins=30)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlabel('age');
plt.show()

# %%
users
# Out:
#       user_id gender  age  occupation    zip
# 0           1      F    1          10  48067
# 1           2      M   56          16  70072
# 2           3      M   25          15  55117
# 3           4      M   45           7  02460
# 4           5      M   25          20  55455
# 5           6      F   50           9  55117
# 6           7      M   35           1  06810
# 7           8      M   25          12  11413
# 8           9      M   25          17  61614
# 9          10      F   35           1  95370
# 10         11      F   25           1  04093
# 11         12      M   25          12  32793
# 12         13      M   45           1  93304
# 13         14      M   35           0  60126
# 14         15      M   25           7  22903
# 15         16      F   35           0  20670
# 16         17      M   50           1  95350
# 17         18      F   18           3  95825
# 18         19      M    1          10  48073
# 19         20      M   25          14  55113
# ...

# %%
# (3) Binning our users and compare ratings across age groups.
import numpy as np
labels = ['0-9', '10-19', '20-29', '30-39', '40-49', '50-59']
data['age_group'] = pd.cut(data.age, range(0, 61, 10), right=False, labels=labels)
data[['age', 'age_group']].drop_duplicates()
data.groupby('age_group').agg({'rating': [np.size, np.mean]})
# explanation: (1) the older people has high rating on films
#              (2) people between 10 - 39 years old are the majority.
# Out:
#            rating
#              size      mean
# age_group
# 0-9         27211  3.549520
# 10-19      183536  3.507573
# 20-29      395556  3.545235
# 30-39      199003  3.618162
# 40-49       83633  3.638062
# 50-59      111270  3.732677
